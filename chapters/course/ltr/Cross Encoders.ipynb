# %% [markdown]
# # Pretrained cross encoders
#
# In this notebook, we see how cross encoders accurately predict the relevance of keywords relative to a passage in the movie dataset.
#
# Cross encoders measure query-doc relevance LATE in the process.
#
# A biencoder encodes the query and document independently into vectors so that similar passages result in higher cosine similarity.
#
# A cross encoder, however, is trained on a different task. It attempts to classify two sentences as relevant for each other or not. The first sentence being a question or query. The second being the passage being ranked.
#
# In both cases the BERT / Transformer "lego piece" is in place, but they are trained on different tasks. One to produce embeddings. The other to produce a classifier.
#
# We use [SentenceTransformers](https://sbert.net/examples/cross_encoder/applications/README.html) cross encoders library which expose pretrained cross-encoders for our usage.
#
# ## Load movie dataset
#
# We load TheMovieDB training set into two pandas dataframes. One with the judgments the other with the movie data

# %%
from ltr.download import download, extract_tgz 
from aips.data_loaders.movies import load_dataframe
import tarfile
import json

dataset = ["https://github.com/ai-powered-search/tmdb/raw/main/judgments.tgz", 
           "https://github.com/ai-powered-search/tmdb/raw/main/movies.tgz"]
download(dataset, dest="data/")
extract_tgz("data/movies.tgz", "data/") # -> Holds "tmdb.json", big json dict with corpus
extract_tgz("data/judgments.tgz", "data/") # -> Holds "ai_pow_search_judgments.txt", 
                                  # which is our labeled judgment list

import pandas as pd
movies = pd.read_json('data/tmdb.json', orient="index")
movies = movies[['title', 'overview']]
movies['title'] = movies['title'].fillna('')
movies['overview'] = movies['overview'].fillna('')

from ltr.judgments import judgments_open
import pandas as pd

all_judgments = []
with judgments_open("data/ai_pow_search_judgments.txt") as judgments:
    for judgment in judgments:
        all_judgments.append({'grade': judgment.grade,
                              'keywords': judgment.keywords,
                              'doc_id': int(judgment.doc_id)})

judgments = pd.DataFrame(all_judgments)
judgments
# Out:
# data/judgments.tgz already exists
# data/movies.tgz already exists

# %% [markdown]
# ## Rerank from the judgments directly
#
# To "simulate" L0 retrieval, here we will just grab candidates directly from the labeled dataset. Usually this would be some top N from your search engine.
#
# Below we'll grab a query `vietnam war` which is a general category. A lot of the vietnam war movies may or may not actually mention it.

# %%
vietnam_war = judgments[judgments['keywords'] == 'vietnam war'].merge(movies,
                                                                      how='left', right_index=True, 
                                                                      left_on='doc_id')

vietnam_war['passage'] = vietnam_war['title'] + '\n\n' + vietnam_war['overview']
vietnam_war
# Out:
#       grade     keywords  doc_id  \
# 3825      1  vietnam war     600
# 3826      1  vietnam war      28
# 3827      1  vietnam war     792
# 3828      1  vietnam war   11778
# 3829      0  vietnam war     437
# 3830      0  vietnam war   11543
# 3831      0  vietnam war   84892
# 3832      0  vietnam war   72890
# 3833      0  vietnam war   70667
# 3834      0  vietnam war   15347
# 3835      0  vietnam war    5143
# 3836      0  vietnam war    9382
# 3837      0  vietnam war   11260
# 3838      0  vietnam war   11674
# 3839      0  vietnam war   49010
# 3840      0  vietnam war   16996
# 3841      0  vietnam war    1649
# 3842      0  vietnam war   29415
# 3843      0  vietnam war   10673
# 3844      0  vietnam war   22575
# 3845      0  vietnam war    7095
# 3846      0  vietnam war   16220
# 3847      0  vietnam war    9741
# 3848      0  vietnam war    9458
# 3849      0  vietnam war  116690
# 3850      0  vietnam war    8271
# 3851      0  vietnam war   13932
# 3852      0  vietnam war  241239
# 3853      0  vietnam war   70435
# 3854      0  vietnam war   60276
# 3855      0  vietnam war   10122
# 3856      0  vietnam war   45929
# 3857      0  vietnam war   20438
# 3858      0  vietnam war     346
# 3859      0  vietnam war   28043
# 3860      0  vietnam war   20417
# 3861      0  vietnam war   61563
# 3862      0  vietnam war   10961
# 3863      0  vietnam war    4806
# 3864      0  vietnam war   10661
# 3865      0  vietnam war   10127
#
#                                                 title  \
# 3825                                Full Metal Jacket
# 3826                                   Apocalypse Now
# 3827                                          Platoon
# 3828                                  The Deer Hunter
# 3829                                Cube 2: Hypercube
# 3830                                          Kingpin
# 3831                  The Perks of Being a Wallflower
# 3832                                 Girl Most Likely
# 3833                                         Kon-Tiki
# 3834                                        Born Free
# 3835                           Hannah and Her Sisters
# 3836                                 Boys on the Side
# 3837                                        Meet Dave
# 3838                                   101 Dalmatians
# 3839                              Hobo with a Shotgun
# 3840                                         17 Again
# 3841                       Bill & Ted's Bogus Journey
# 3842                                  La Bête Humaine
# 3843                                      Wall Street
# 3844                                          Go West
# 3845                                             Jack
# 3846                                          Wizards
# 3847                                      Unbreakable
# 3848                               Desperate Measures
# 3849                           The Ballad of Narayama
# 3850                                        Disturbia
# 3851                                 Jack-Jack Attack
# 3852                              A Most Violent Year
# 3853                                          Haywire
# 3854  Scenes from the Class Struggle in Beverly Hills
# 3855                          Flight of the Navigator
# 3856                                         Titanica
# 3857                                 The Tao of Steve
# 3858                                    Seven Samurai
# 3859                                    Black Sabbath
# 3860                                  Dressed to Kill
# 3861                                            Touch
# 3862       Behind the Mask: The Rise of Leslie Vernon
# 3863                                    Runaway Bride
# 3864                    You Don't Mess with the Zohan
# 3865                                       Critters 2
#
#                                                overview  \
# 3825  A pragmatic U.S. Marine observes the dehumaniz...
# 3826  At the height of the Vietnam war, Captain Benj...
# 3827  As a young and naive recruit in Vietnam, Chris...
# 3828  A group of working-class friends decides to en...
# 3829  The sequel to the low budget first film ‘Cube....
# 3830  After bowler Roy Munson swindles the wrong cro...
# 3831  Pittsburgh, Pennsylvania, 1991. High school fr...
# 3832  A failed New York playwright stages a suicide ...
# 3833  The true story about legendary explorer Thor H...
# 3834  At a national park in Kenya, English game ward...
# 3835  Between two Thanksgivings, Hannah's husband fa...
# 3836  After breaking up with her girlfriend, a night...
# 3837  A crew of miniature aliens operate a spaceship...
# 3838  The Live action adaptation of a Disney Classic...
# 3839  A vigilante homeless man pulls into a new city...
# 3840  On the brink of a midlife crisis, 30-something...
# 3841  Amiable slackers Bill and Ted are once again r...
# 3842  In this classic adaptation of Emile Zola's nov...
# 3843  A young and impatient stockbroker is willing t...
# 3844  Embezzler, shill, all around confidence man S....
# 3845  Jack Powell suffers from an affliction that ma...
# 3846  In a post-apocalyptic future, humankind is des...
# 3847  An ordinary man makes an extraordinary discove...
# 3848  San Francisco police officer Frank Connor is i...
# 3849  In Kabuki style, the film tells the story of a...
# 3850  Kale is a 17-year-old placed under house arres...
# 3851  Kari the babysitter thinks she's in for a nigh...
# 3852  A thriller set in New York City during the win...
# 3853  Mallory Kane is a highly trained operative who...
# 3854  The widow's houseboy and the divorcee's chauff...
# 3855  12-year-old David is accidentally knocked out ...
# 3856  Titanica is a fascinating non-fiction drama wh...
# 3857  Underachieving, overweight kindergarten teache...
# 3858  A veteran samurai, who has fallen on hard time...
# 3859  Black Sabbath is a 1963 Italian horror film di...
# 3860  A convicted thief in Dartmoor prison hides the...
# 3861  When Juvenal, a presumed miracle worker, appea...
# 3862  The next great psycho horror slasher has given...
# 3863  Ike Graham, New York columnist, writes his tex...
# 3864  An Israeli counterterrorism soldier with a sec...
# 3865  A batch of unhatched critter eggs are mistaken...
#
#                                                 passage
# 3825  Full Metal Jacket\n\nA pragmatic U.S. Marine o...
# 3826  Apocalypse Now\n\nAt the height of the Vietnam...
# 3827  Platoon\n\nAs a young and naive recruit in Vie...
# 3828  The Deer Hunter\n\nA group of working-class fr...
# 3829  Cube 2: Hypercube\n\nThe sequel to the low bud...
# 3830  Kingpin\n\nAfter bowler Roy Munson swindles th...
# 3831  The Perks of Being a Wallflower\n\nPittsburgh,...
# 3832  Girl Most Likely\n\nA failed New York playwrig...
# 3833  Kon-Tiki\n\nThe true story about legendary exp...
# 3834  Born Free\n\nAt a national park in Kenya, Engl...
# 3835  Hannah and Her Sisters\n\nBetween two Thanksgi...
# 3836  Boys on the Side\n\nAfter breaking up with her...
# 3837  Meet Dave\n\nA crew of miniature aliens operat...
# 3838  101 Dalmatians\n\nThe Live action adaptation o...
# 3839  Hobo with a Shotgun\n\nA vigilante homeless ma...
# 3840  17 Again\n\nOn the brink of a midlife crisis, ...
# 3841  Bill & Ted's Bogus Journey\n\nAmiable slackers...
# 3842  La Bête Humaine\n\nIn this classic adaptation ...
# 3843  Wall Street\n\nA young and impatient stockbrok...
# 3844  Go West\n\nEmbezzler, shill, all around confid...
# 3845  Jack\n\nJack Powell suffers from an affliction...
# 3846  Wizards\n\nIn a post-apocalyptic future, human...
# 3847  Unbreakable\n\nAn ordinary man makes an extrao...
# 3848  Desperate Measures\n\nSan Francisco police off...
# 3849  The Ballad of Narayama\n\nIn Kabuki style, the...
# 3850  Disturbia\n\nKale is a 17-year-old placed unde...
# 3851  Jack-Jack Attack\n\nKari the babysitter thinks...
# 3852  A Most Violent Year\n\nA thriller set in New Y...
# 3853  Haywire\n\nMallory Kane is a highly trained op...
# 3854  Scenes from the Class Struggle in Beverly Hill...
# 3855  Flight of the Navigator\n\n12-year-old David i...
# 3856  Titanica\n\nTitanica is a fascinating non-fict...
# 3857  The Tao of Steve\n\nUnderachieving, overweight...
# 3858  Seven Samurai\n\nA veteran samurai, who has fa...
# 3859  Black Sabbath\n\nBlack Sabbath is a 1963 Itali...
# 3860  Dressed to Kill\n\nA convicted thief in Dartmo...
# 3861  Touch\n\nWhen Juvenal, a presumed miracle work...
# 3862  Behind the Mask: The Rise of Leslie Vernon\n\n...
# 3863  Runaway Bride\n\nIke Graham, New York columnis...
# 3864  You Don't Mess with the Zohan\n\nAn Israeli co...
# 3865  Critters 2\n\nA batch of unhatched critter egg...

# %% [markdown]
# ## Rerank based on keyword -- passage similarity
#
# The cross encoder will rerank using the similarity between keywords and the passage. Below we gather those into `pairs` then ask the model to score each pair, placing it back in the dataframe. Finally we sort on this score from most to least relevant.
#
# ### Awesome
#
# You can see this works very well to rank based on semantics!
#
# ### Not so awesome
#
# The cross encoder doesn't have a straight-forward way to include other types of features we might want in an LTR solution. Such as numerical features (popularity, etc). Nor do we have direct keyword matches.
#
# For these reasons traditional LTR persists with the cross encoder / bi encoders providing one piece of the puzzle.

# %%
from time import perf_counter

model = CrossEncoder("cross-encoder/ms-marco-MiniLM-L6-v2")
pairs = vietnam_war[['keywords', 'passage']].to_records(index=False)
scores = model.predict(pairs)
vietnam_war['scores'] = scores

# %%
vietnam_war.sort_values('scores', ascending=False)
# Out:
#       grade     keywords  doc_id  \
# 3826      1  vietnam war      28
# 3828      1  vietnam war   11778
# 3825      1  vietnam war     600
# 3827      1  vietnam war     792
# 3846      0  vietnam war   16220
# 3859      0  vietnam war   28043
# 3856      0  vietnam war   45929
# 3858      0  vietnam war     346
# 3844      0  vietnam war   22575
# 3853      0  vietnam war   70435
# 3852      0  vietnam war  241239
# 3864      0  vietnam war   10661
# 3861      0  vietnam war   61563
# 3835      0  vietnam war    5143
# 3845      0  vietnam war    7095
# 3851      0  vietnam war   13932
# 3849      0  vietnam war  116690
# 3834      0  vietnam war   15347
# 3848      0  vietnam war    9458
# 3842      0  vietnam war   29415
# 3850      0  vietnam war    8271
# 3831      0  vietnam war   84892
# 3857      0  vietnam war   20438
# 3833      0  vietnam war   70667
# 3839      0  vietnam war   49010
# 3847      0  vietnam war    9741
# 3863      0  vietnam war    4806
# 3865      0  vietnam war   10127
# 3840      0  vietnam war   16996
# 3862      0  vietnam war   10961
# 3836      0  vietnam war    9382
# 3855      0  vietnam war   10122
# 3841      0  vietnam war    1649
# 3838      0  vietnam war   11674
# 3860      0  vietnam war   20417
# 3829      0  vietnam war     437
# 3843      0  vietnam war   10673
# 3854      0  vietnam war   60276
# 3837      0  vietnam war   11260
# 3830      0  vietnam war   11543
# 3832      0  vietnam war   72890
#
#                                                 title  \
# 3826                                   Apocalypse Now
# 3828                                  The Deer Hunter
# 3825                                Full Metal Jacket
# 3827                                          Platoon
# 3846                                          Wizards
# 3859                                    Black Sabbath
# 3856                                         Titanica
# 3858                                    Seven Samurai
# 3844                                          Go West
# 3853                                          Haywire
# 3852                              A Most Violent Year
# 3864                    You Don't Mess with the Zohan
# 3861                                            Touch
# 3835                           Hannah and Her Sisters
# 3845                                             Jack
# 3851                                 Jack-Jack Attack
# 3849                           The Ballad of Narayama
# 3834                                        Born Free
# 3848                               Desperate Measures
# 3842                                  La Bête Humaine
# 3850                                        Disturbia
# 3831                  The Perks of Being a Wallflower
# 3857                                 The Tao of Steve
# 3833                                         Kon-Tiki
# 3839                              Hobo with a Shotgun
# 3847                                      Unbreakable
# 3863                                    Runaway Bride
# 3865                                       Critters 2
# 3840                                         17 Again
# 3862       Behind the Mask: The Rise of Leslie Vernon
# 3836                                 Boys on the Side
# 3855                          Flight of the Navigator
# 3841                       Bill & Ted's Bogus Journey
# 3838                                   101 Dalmatians
# 3860                                  Dressed to Kill
# 3829                                Cube 2: Hypercube
# 3843                                      Wall Street
# 3854  Scenes from the Class Struggle in Beverly Hills
# 3837                                        Meet Dave
# 3830                                          Kingpin
# 3832                                 Girl Most Likely
#
#                                                overview  \
# 3826  At the height of the Vietnam war, Captain Benj...
# 3828  A group of working-class friends decides to en...
# 3825  A pragmatic U.S. Marine observes the dehumaniz...
# 3827  As a young and naive recruit in Vietnam, Chris...
# 3846  In a post-apocalyptic future, humankind is des...
# 3859  Black Sabbath is a 1963 Italian horror film di...
# 3856  Titanica is a fascinating non-fiction drama wh...
# 3858  A veteran samurai, who has fallen on hard time...
# 3844  Embezzler, shill, all around confidence man S....
# 3853  Mallory Kane is a highly trained operative who...
# 3852  A thriller set in New York City during the win...
# 3864  An Israeli counterterrorism soldier with a sec...
# 3861  When Juvenal, a presumed miracle worker, appea...
# 3835  Between two Thanksgivings, Hannah's husband fa...
# 3845  Jack Powell suffers from an affliction that ma...
# 3851  Kari the babysitter thinks she's in for a nigh...
# 3849  In Kabuki style, the film tells the story of a...
# 3834  At a national park in Kenya, English game ward...
# 3848  San Francisco police officer Frank Connor is i...
# 3842  In this classic adaptation of Emile Zola's nov...
# 3850  Kale is a 17-year-old placed under house arres...
# 3831  Pittsburgh, Pennsylvania, 1991. High school fr...
# 3857  Underachieving, overweight kindergarten teache...
# 3833  The true story about legendary explorer Thor H...
# 3839  A vigilante homeless man pulls into a new city...
# 3847  An ordinary man makes an extraordinary discove...
# 3863  Ike Graham, New York columnist, writes his tex...
# 3865  A batch of unhatched critter eggs are mistaken...
# 3840  On the brink of a midlife crisis, 30-something...
# 3862  The next great psycho horror slasher has given...
# 3836  After breaking up with her girlfriend, a night...
# 3855  12-year-old David is accidentally knocked out ...
# 3841  Amiable slackers Bill and Ted are once again r...
# 3838  The Live action adaptation of a Disney Classic...
# 3860  A convicted thief in Dartmoor prison hides the...
# 3829  The sequel to the low budget first film ‘Cube....
# 3843  A young and impatient stockbroker is willing t...
# 3854  The widow's houseboy and the divorcee's chauff...
# 3837  A crew of miniature aliens operate a spaceship...
# 3830  After bowler Roy Munson swindles the wrong cro...
# 3832  A failed New York playwright stages a suicide ...
#
#                                                 passage     scores
# 3826  Apocalypse Now\n\nAt the height of the Vietnam...   3.105940
# 3828  The Deer Hunter\n\nA group of working-class fr...   2.455610
# 3825  Full Metal Jacket\n\nA pragmatic U.S. Marine o...   1.755414
# 3827  Platoon\n\nAs a young and naive recruit in Vie...   0.254646
# 3846  Wizards\n\nIn a post-apocalyptic future, human... -10.406036
# 3859  Black Sabbath\n\nBlack Sabbath is a 1963 Itali... -10.720423
# 3856  Titanica\n\nTitanica is a fascinating non-fict... -10.844439
# 3858  Seven Samurai\n\nA veteran samurai, who has fa... -10.864466
# 3844  Go West\n\nEmbezzler, shill, all around confid... -10.882360
# 3853  Haywire\n\nMallory Kane is a highly trained op... -10.915937
# 3852  A Most Violent Year\n\nA thriller set in New Y... -10.952652
# 3864  You Don't Mess with the Zohan\n\nAn Israeli co... -10.965057
# 3861  Touch\n\nWhen Juvenal, a presumed miracle work... -10.985085
# 3835  Hannah and Her Sisters\n\nBetween two Thanksgi... -11.002594
# 3845  Jack\n\nJack Powell suffers from an affliction... -11.004313
# 3851  Jack-Jack Attack\n\nKari the babysitter thinks... -11.014374
# 3849  The Ballad of Narayama\n\nIn Kabuki style, the... -11.015432
# 3834  Born Free\n\nAt a national park in Kenya, Engl... -11.028400
# 3848  Desperate Measures\n\nSan Francisco police off... -11.029266
# 3842  La Bête Humaine\n\nIn this classic adaptation ... -11.029446
# 3850  Disturbia\n\nKale is a 17-year-old placed unde... -11.040276
# 3831  The Perks of Being a Wallflower\n\nPittsburgh,... -11.045349
# 3857  The Tao of Steve\n\nUnderachieving, overweight... -11.073734
# 3833  Kon-Tiki\n\nThe true story about legendary exp... -11.076086
# 3839  Hobo with a Shotgun\n\nA vigilante homeless ma... -11.077403
# 3847  Unbreakable\n\nAn ordinary man makes an extrao... -11.083710
# 3863  Runaway Bride\n\nIke Graham, New York columnis... -11.085125
# 3865  Critters 2\n\nA batch of unhatched critter egg... -11.092989
# 3840  17 Again\n\nOn the brink of a midlife crisis, ... -11.095716
# 3862  Behind the Mask: The Rise of Leslie Vernon\n\n... -11.098706
# 3836  Boys on the Side\n\nAfter breaking up with her... -11.110653
# 3855  Flight of the Navigator\n\n12-year-old David i... -11.112480
# 3841  Bill & Ted's Bogus Journey\n\nAmiable slackers... -11.112887
# 3838  101 Dalmatians\n\nThe Live action adaptation o... -11.112946
# 3860  Dressed to Kill\n\nA convicted thief in Dartmo... -11.131363
# 3829  Cube 2: Hypercube\n\nThe sequel to the low bud... -11.134874
# 3843  Wall Street\n\nA young and impatient stockbrok... -11.136807
# 3854  Scenes from the Class Struggle in Beverly Hill... -11.177336
# 3837  Meet Dave\n\nA crew of miniature aliens operat... -11.182146
# 3830  Kingpin\n\nAfter bowler Roy Munson swindles th... -11.187874
# 3832  Girl Most Likely\n\nA failed New York playwrig... -11.206976
