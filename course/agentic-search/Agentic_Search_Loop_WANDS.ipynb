# %% [markdown]
# # Let's build an agentic search loop!
#
# This notebook has a basic agentic search loop
#
# * We have a set of furniture in our catalog
# * We tell the Agent our preferences
# * The agent uses the search tool to recommend furniture
#
# In this notebook we mostly get a feel for how the overall loop works by unrolling it step by step

# %%
import os
os.environ["CHEAT_AT_SEARCH_DATA_PATH"] = "/home/jovyan/data"

from cheat_at_search.data_dir import mount
mount(use_gdrive=False)    # colab, share data across notebook runs on gdrive
# mount(use_gdrive=False) # <- colab without gdrive
# mount(use_gdrive=False, manual_path="/path/to/directory")  # <- force data path to specific directory, ie you're running locally.

# %% [markdown]
# ## Get an OpenAI Key
#
# This will prompt you for an OpenAI Key to interact with GPT-5

# %%
from cheat_at_search.data_dir import key_for_provider
from openai import OpenAI

OPENAI_KEY = key_for_provider("openai")

openai = OpenAI(api_key=OPENAI_KEY)

# %% [markdown]
# ## Load the Wayfair corpus
#
# We'll recommend products only from this corpus

# %%
from cheat_at_search.wands_data import corpus
corpus
# Out:
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count  \
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
#                                                 features  doc_id  \
# 0      [overallwidth-sidetoside:64.7, dsprimaryproduc...       0
# 1      [capacityquarts:7, producttype : slow cooker, ...       1
# 2      [features : keep warm setting, capacityquarts:...       2
# 3      [overallwidth-sidetoside:3.5, warrantylength :...       3
# 4      [compatibledoorthickness:1.375 '' , countryofo...       4
# ...                                                  ...     ...
# 42989  [producttype : shower panel, spraypattern : ra...   42989
# 42990  [basematerialdetails : steel,  : gray wood, of...   42990
# 42991  [additionaltoolsrequirednotincluded : power dr...   42991
# 42992  [legmaterialdetails : rubberwood, backheight-s...   42992
# 42993  [distancebetweenfloorandfootrest:7.5, dssecond...   42993
#
#                                                    title  \
# 0                                solid wood platform bed
# 1                            all-clad 7 qt . slow cooker
# 2                all-clad electrics 6.5 qt . slow cooker
# 3           all-clad all professional tools pizza cutter
# 4      baldwin prestige alcott passage knob with roun...
# ...                                                  ...
# 42989  malibu pressure balanced diverter fixed shower...
# 42990              emmeline 5 piece breakfast dining set
# 42991                      maloney 3 piece pub table set
# 42992           fletcher 27.5 '' wide polyester armchair
# 42993                            griffin 29 '' bar stool
#
#                                              description            category  \
# 0      good , deep sleep can be quite difficult to ha...           Furniture
# 1      create delicious slow-cooked meals , from tend...  Kitchen & Tabletop
# 2      prepare home-cooked meals on any schedule with...  Kitchen & Tabletop
# 3      this original stainless tool was designed to c...     Browse By Brand
# 4      the hardware has a rich heritage of delivering...    Home Improvement
# ...                                                  ...                 ...
# 42989  the malibu pressure balanced diverter fixed sh...    Home Improvement
# 42990                                                              Furniture
# 42991  this pub table set includes 1 counter height t...           Furniture
# 42992  bring iconic , modern style to your space in a...           Furniture
# 42993  this set of two barstools features a minimalis...           Furniture
#
#                                sub_category  \
# 0                         Bedroom Furniture
# 1                  Small Kitchen Appliances
# 2                  Small Kitchen Appliances
# 3                                  All-Clad
# 4                     Doors & Door Hardware
# ...                                     ...
# 42989  Bathroom Remodel & Bathroom Fixtures
# 42990            Kitchen & Dining Furniture
# 42991            Kitchen & Dining Furniture
# 42992                 Living Room Furniture
# 42993            Kitchen & Dining Furniture
#
#                                               cat_subcat  \
# 0                          Furniture / Bedroom Furniture
# 1          Kitchen & Tabletop / Small Kitchen Appliances
# 2          Kitchen & Tabletop / Small Kitchen Appliances
# 3                             Browse By Brand / All-Clad
# 4               Home Improvement / Doors & Door Hardware
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990             Furniture / Kitchen & Dining Furniture
# 42991             Furniture / Kitchen & Dining Furniture
# 42992                  Furniture / Living Room Furniture
# 42993             Furniture / Kitchen & Dining Furniture
#
#                                           title_snowball  \
# 0            Terms({'bed', 'wood', 'platform', 'solid'})
# 1      Terms({'cooker', '7', 'qt', 'slow', 'all', 'cl...
# 2      Terms({'cooker', 'qt', '5', 'slow', '6', 'all'...
# 3      Terms({'profession', 'cutter', 'tool', 'pizza'...
# 4      Terms({'knob', 'alcott', 'with', 'prestig', 'b...
# ...                                                  ...
# 42989  Terms({'pressur', 'balanc', 'fix', 'divert', '...
# 42990  Terms({'set', 'dine', '5', 'emmelin', 'breakfa...
# 42991  Terms({'set', 'tabl', '3', 'maloney', 'pub', '...
# 42992  Terms({'armchair', '5', 'fletcher', 'polyest',...
# 42993           Terms({'stool', 'griffin', '29', 'bar'})
#
#                                     description_snowball
# 0      Terms({'there', 'under', 'place', 'hybrid', 's...
# 1      Terms({'place', 'cook', 'size', 'slow', 'walk'...
# 2      Terms({'cook', '26', 'slow', 'a', 'schedul', '...
# 3      Terms({'complement', 'a', 'tool', 'was', 'shar...
# 4      Terms({'door', 'inspir', 'creat', 'dummi', 'mo...
# ...                                                  ...
# 42989  Terms({'balanc', 'divert', 'into', 'a', 'conte...
# 42990                                       Terms(set())
# 42991  Terms({'under', 'space', 'or', 'place', 'creat...
# 42992  Terms({'fill', 'space', 'sinuous', 'comfort', ...
# 42993  Terms({'metal', 'adjust', 'rustic', 'great', '...
#
# [42994 rows x 18 columns]

# %% [markdown]
# ### Index the furniture
#
# We'll index title and description with basic stemming to be able to retrieve them

# %%
from searcharray import SearchArray
from cheat_at_search.tokenizers import snowball_tokenizer

corpus['title_snowball'] = SearchArray.index(corpus['title'].fillna(''), snowball_tokenizer)
corpus['description_snowball'] = SearchArray.index(corpus['description'].fillna(''), snowball_tokenizer)
# Out:
# 2026-04-02 01:16:20,254 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2026-04-02 01:16:20,257 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2026-04-02 01:16:20,258 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2026-04-02 01:16:20,349 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2026-04-02 01:16:20,437 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2026-04-02 01:16:20,524 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2026-04-02 01:16:20,611 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2026-04-02 01:16:20,659 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2026-04-02 01:16:20,663 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2026-04-02 01:16:20,666 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2026-04-02 01:16:20,682 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2026-04-02 01:16:20,697 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2026-04-02 01:16:20,698 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2026-04-02 01:16:20,712 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2026-04-02 01:16:20,723 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2026-04-02 01:16:20,725 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2026-04-02 01:16:20,726 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2026-04-02 01:16:21,089 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2026-04-02 01:16:21,452 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2026-04-02 01:16:21,845 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2026-04-02 01:16:22,219 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2026-04-02 01:16:22,379 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2026-04-02 01:16:22,405 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2026-04-02 01:16:22,434 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2026-04-02 01:16:22,614 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2026-04-02 01:16:22,698 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2026-04-02 01:16:22,700 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2026-04-02 01:16:22,786 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete

# %% [markdown]
# ## Create a furniture products search function
#
# Here is a function that searches a Wayfair product dataset. It's just a Python function that returns top 10 pieces of furniture.
#
# Right now we'll call it directly, soon we'll help ChatGPT interact with this.

# %%
import numpy as np
from typing import Union

def search_furniture(keywords: str) -> list[dict[str, Union[str, int, float]]]:
    """Search the available furniture products, get top 10 furniture.

    This is just a naive BM25 / keyword search of the product title and description.
    Don't expect sophisticated synonyms or semantic search. Just basic keyword with
    some stemming.

    """
    print("search", keywords)
    required_keywords = [term[1:] for term in keywords.split() if term.startswith("+")]
    bm25_scores = np.zeros(len(corpus))
    for term in snowball_tokenizer(keywords):
        bm25_scores += corpus['title_snowball'].array.score(term) * 7
        bm25_scores += corpus['description_snowball'].array.score(term) * 4

    for required_term in snowball_tokenizer(" ".join(required_keywords)):
        required_score = (corpus['title_snowball'].array.score(required_term) +
                          corpus['description_snowball'].array.score(required_term))
        bm25_scores[required_score == 0] = 0

    top_k_indices = np.argsort(bm25_scores)[-10:][::-1]
    bm25_scores = bm25_scores[top_k_indices]
    top_movies = corpus.iloc[top_k_indices].copy()
    top_movies.loc[:, 'score'] = bm25_scores

    results = []
    for id, row in top_movies.iterrows():
        results.append({
            'id': row['doc_id'],
            'title': row['title'],
            'description': row['description'],
            'score': row['score']
        })
    return results



search_furniture("geometric style +couch")
# Out:
# search geometric style +couch
# [{'id': 1217,
#   'title': 'extra large and wide couch riser',
#   'description': 'our largest and oversized couch , furniture , and bed riser . made for those extra-large couch and furniture legs . we created these to allow one time stacking . tested to lift over 6,000 pounds - we made it heavy duty . includes a leather pad to keep legs from sliding off the top and a rubber base to prevent slipping on the floor . fits almost all sofas , couches , beds , large legs , and feet .',
#   'score': 37.797197341918945},
#  {'id': 25326,
#   'title': 'pixar cars 2 in 1 flip open kids foam couch',
#   'description': "now your little one can have their very own place to sit with the marshmallow furniture children 's 2-in-1 flip open foam kids sofa . this couch for toddlers is the perfect place for them to call their own while they read , eat snacks , watch tv , or nap . this marshmallow furniture children 's 2-in-1 flip open foam futon-style sofa is made of lightweight foam so kiddos can move it around from room to room themselves , flipping it open into a bed or folding it back into a sofa . this kid 's sofa makes a great gift , and it will fit right into playrooms , bedrooms , living rooms , daycare , sleepovers , vacations , or nap time . this particular marshmallow furniture kids sofa comes with a fun disney pixar cars 3 print , and parents will love the machine-washable zippered polyester fabric slipcover .",
#   'score': 26.853947281837463},
#  {'id': 10322,
#   'title': 'rundle couch bubbles throw pillow',
#   'description': 'the manufacturer works with artists from around the world to create astouding and unique home decor products . toss this decorative pillow on any bed , sofa or chair , and add personality to your chic and stylish decor . lay your head against your new art and relax ! all orders are subject to a possible shipping credit if you order a combination of products and pieces in one order . each purchase supports the artist who created the image . made of woven polyester material that is super soft and cozy . includes a cushy supportive pillow insert , zipped inside . dye sublimation printing adheres the ink to the material for long life and durability .',
#   'score': 25.523414611816406},
#  {'id': 10320,
#   'title': 'nava couch owl throw pillow',
#   'description': 'the manufacturer works with artists from around the world to create astounding and unique home decor products . toss this decorative pillow on any bed , sofa or chair , and add personality to your chic and stylish decor . lay your head against your new art and relax ! all orders are subject to a possible shipping credit if you order a combination of products and pieces in one order . each purchase supports the artist who created the image . made of woven polyester material that is super soft and cozy . includes a cushy supportive pillow insert , zipped inside . dye-sublimation printing adheres the ink to the material for long life and durability .',
#   'score': 25.523414611816406},
#  {'id': 824,
#   'title': 'double chaise lounge floor couch',
#   'description': "the multi-functional lazy sofa is becoming a popular trend for people to enjoy themselves after their tiring work every day . it is great for almost every place , such as living room , bedroom , home office , dorm room , balcony , and outdoor space , and suitable for watching tv , play games , working on a laptop , or take a nap in it . you wo n't be disappointed with this purchase . lean back and get comfortable after a long day with the leisure sofa bed with a built-in 5 gear back adjuster system and take floor comfort to the next level . the built-in back adjuster system allows the chair to easily take on 5 different angled positions from 90 degrees in an upright chair position to 180 degrees flatbed position , satisfying any and all posture requirements for a customized seating experience .",
#   'score': 25.523414611816406},
#  {'id': 23758,
#   'title': 'double chaise lounge sofa floor couch',
#   'description': 'the multifunctional lazy sofa has become a popular trend for people to enjoy life after hard work every day . it can be placed almost everywhere , such as living room , bedroom , home office , dormitory , balcony , and outdoor space . it is very suitable for you to watch tv , play games , play on your laptop , or have a nap . therefore , this purchase will definitely not disappoint you . this built-in leisure sofa features a 5-gear back adjustment system that allows you to enjoy comfort after a busy day . this sofa , from 90 degrees in an upright chair position to a 180 degrees flatbed position , can satisfy any posture requirements of you to achieve a customized seating experience and provide you with a new solution to increase floor comfort .',
#   'score': 23.870174407958984},
#  {'id': 33593,
#   'title': 'sectional couch with reversible chaise modern l-shape sofa 3-seat couch modular sectional sofa',
#   'description': 'this reversible l-shaped sofa can be a free combination . the ottoman moves left or right or middle according to your needs . even the middle seat can be move as a single seat . then 3-person seats become 2-person ‘ s . let you feel different space . the friendly design is very suitable for your home .',
#   'score': 23.251253128051758},
#  {'id': 543,
#   'title': 'waytrim indoor chaise lounge sofa , folding lazy sofa floor chair 6-position folding padded , lounger bed with armrests and a pillow chaise couch - gray',
#   'description': 'waytrim indoor chaise lounge sofa , folding lazy sofa floor chair 6-position folding padded , lounger bed with armrests and a pillow chaise couch - gray .',
#   'score': 23.161453247070312},
#  {'id': 33595,
#   'title': 'convertible modular sectional sofa u shaped couch with reversible chaise modular couch sectional sofa with ottomans',
#   'description': 'filled with a high-quality sponge , making this sectional sofa is beautiful and comfortable . it can be perfectly matched with your living room or conference . for convenience and need you also can move and assemble any module , this is the charm of the modular sectional sofa !',
#   'score': 22.540176391601562},
#  {'id': 31141,
#   'title': 'convertible sectional sofa couch , l-shaped couch with modern linen fabric for small space dark grey',
#   'description': 'small sofa and space-saving : modern and stylish design indoor sofa set fit perfectly with any indoor decor . this sofa sets clean lines , solid construction , and a comfortable finish that the whole family will love , perfect for an apartment , a studio , a condo , or a small space . this small space reversible sectional sofa that works well in any corner or living room . chaise lounge base can go on the left or right freely as you like . sports velcros on the bottom of the cushions can avoid slipping when seating .',
#   'score': 22.540176391601562}]

# %% [markdown]
# ## Describe the search tool to the LLM
#
# There is a specific schema for telling OpenAI about our tools / functions. However, the cheat at search library has added some conveniences:
#
# * We use the function name as the name to OpenAI
# * We use the doc string to get a description
# * The typing information gets encoded in parameters and return value
#
# So IMPORTANTLY -- all these things are part of the prompt
#
# ### Annoying serialization / deserialization
#
# When we get it in an OpenAI-friendly format, we also keep around some book-keeping for annoying serialization / deserialization of the arguments
#
# With this we get some plumbing information in a 3-tuple
# * The arguments to pass (as one pydantic struct)
# * The tool as OpenAI sees it
# * The function to call to delegate to this tool
#
# Don't get too lost in the weeds here. In future notebooks, cheat-at-search helper code will just do this for you behind the scenes.

# %%
from cheat_at_search.agent.pydantize import make_tool_adapter
search_tool = make_tool_adapter(search_furniture)

tool_info = {search_furniture.__name__: search_tool}
tool_info
# Out:
# {'search_furniture': (cheat_at_search.agent.pydantize.Search_furnitureArgs,
#   {'type': 'function',
#    'name': 'search_furniture',
#    'description': "Search the available furniture products, get top 10 furniture.\n\n    This is just a naive BM25 / keyword search of the product title and description.\n    Don't expect sophisticated synonyms or semantic search. Just basic keyword with\n    some stemming.",
#    'parameters': {'properties': {'keywords': {'title': 'Keywords',
#       'type': 'string'}},
#     'required': ['keywords'],
#     'title': 'Search_furnitureArgs',
#     'type': 'object'}},
#   <function cheat_at_search.agent.pydantize.make_tool_adapter.<locals>.call_from_tool(d: dict, agent_state: dict | None = None)>)}

# %%
import json
print(json.dumps(tool_info['search_furniture'][1], indent=2))
# Out:
# {
#   "type": "function",
#   "name": "search_furniture",
#   "description": "Search the available furniture products, get top 10 furniture.\n\n    This is just a naive BM25 / keyword search of the product title and description.\n    Don't expect sophisticated synonyms or semantic search. Just basic keyword with\n    some stemming.",
#   "parameters": {
#     "properties": {
#       "keywords": {
#         "title": "Keywords",
#         "type": "string"
#       }
#     },
#     "required": [
#       "keywords"
#     ],
#     "title": "Search_furnitureArgs",
#     "type": "object"
#   }
# }

# %% [markdown]
# ## Gather initial prompts
#
# * System prompt - the general task, to lookup furniture in our catalog to recommend
# * User prompt - what the user has given as a task (here listing the movies they like)

# %%
system_prompt = """
Users are coming to explore a catalog of furniture.

Use the search tool (search_furniture) to help them
"""

inputs = []
inputs.append({"role": "system", "content": system_prompt})

prompt = """
Help me find a modern couch with geometric style
"""

inputs.append({"role": "user", "content": prompt})
inputs
# Out:
# [{'role': 'system',
#   'content': '\nUsers are coming to explore a catalog of furniture.\n\nUse the search tool (search_furniture) to help them\n'},
#  {'role': 'user',
#   'content': '\nHelp me find a modern couch with geometric style\n'}]

# %% [markdown]
# ## Make a single call to the LLM (non-tool)
#
# We make a call to the agent, and get some decent recommendations back. But without using the catalog to lookup what's available.

# %%
resp = openai.responses.create(
    model="gpt-5",
    input=inputs,
)
resp
# Out:
# Response(id='resp_090d57d02447da380069cdc3701c7c819790fe27a965115e88', created_at=1775092592.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_090d57d02447da380069cdc3708d508197b3145cd075f6d864', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_090d57d02447da380069cdc37fbc10819781a66b9cac28ad3c', content=[ResponseOutputText(annotations=[], text='Great—let’s narrow it down and I’ll pull matches from the catalog.\n\nA few quick preferences:\n- Type: standard sofa or sectional/chaise?\n- Size: ideal length (e.g., ~72", ~84", 90"+)?\n- Upholstery: performance fabric, leather, velvet, boucle?\n- Color: neutrals or bold tones?\n- Budget range?\n- Delivery ZIP (to check availability)?\n\nFor “geometric” specifically, do you prefer any of these details:\n- Boxy, low-profile silhouette with track arms\n- Grid or channel tufting\n- Angular metal legs\n- Quilted/stitched geometric patterns\n\nShare your picks and I’ll search the catalog for the best modern geometric couches that fit.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=45, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=1171, output_tokens_details=OutputTokensDetails(reasoning_tokens=960), total_tokens=1216), user=None, billing={'payer': 'openai'}, completed_at=1775092610, frequency_penalty=0.0, presence_penalty=0.0, prompt_cache_retention=None, store=True)

# %% [markdown]
# ## Tell the agent about a tool
#
# We tell the agent about the tools it can use. Note the agent doesn't directly "call" the tools (there's no magic backdoor from OpenAI -> this notebook). Insetad, once the agent knows about the tool it can REQUEST we call them.

# %%
resp = openai.responses.create(
    model="gpt-5",
    input=inputs,
    tools=[tool[1] for tool in tool_info.values()],
)
inputs += resp.output
resp
# Out:
# Response(id='resp_0fb18f3031b8c9620069cdc382ae8c81959a8747191ae698fe', created_at=1775092610.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_0fb18f3031b8c9620069cdc383112881958934e7ca181119cb', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseFunctionToolCall(arguments='{"keywords":"modern couch geometric sofa clean lines angular"}', call_id='call_EwlMsxfuInAEYxcW01kPZ646', name='search_furniture', type='function_call', id='fc_0fb18f3031b8c9620069cdc385c8648195bf181073b8aacb8b', status='completed')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='search_furniture', parameters={'properties': {'keywords': {'title': 'Keywords', 'type': 'string'}}, 'required': ['keywords'], 'title': 'Search_furnitureArgs', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description="Search the available furniture products, get top 10 furniture.\n\n    This is just a naive BM25 / keyword search of the product title and description.\n    Don't expect sophisticated synonyms or semantic search. Just basic keyword with\n    some stemming.")], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=131, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=222, output_tokens_details=OutputTokensDetails(reasoning_tokens=192), total_tokens=353), user=None, billing={'payer': 'openai'}, completed_at=1775092614, frequency_penalty=0.0, presence_penalty=0.0, prompt_cache_retention=None, store=True)

# %%
resp.output
# Out:
# [ResponseReasoningItem(id='rs_0fb18f3031b8c9620069cdc383112881958934e7ca181119cb', summary=[], type='reasoning', content=None, encrypted_content=None, status=None),
#  ResponseFunctionToolCall(arguments='{"keywords":"modern couch geometric sofa clean lines angular"}', call_id='call_EwlMsxfuInAEYxcW01kPZ646', name='search_furniture', type='function_call', id='fc_0fb18f3031b8c9620069cdc385c8648195bf181073b8aacb8b', status='completed')]

# %% [markdown]
# ## Issue the requested calls to your search tool
#
# Now we do the magic of calling the tools directly
#
# You can ignore the `annoying_tool_marshalling` its doing some lookups and plumbings to go between the JSON arguments and the Python world we have here.
#
# The important thing is that we recieve a tool call request, we call the requested tool (here by doing a lookup and getting `tool_fn` that just wraps the search function)
#
# Then we go on to append those all back into th inputs, with a JSON response, the call id, and a note to OpenAI this is a "function_call_output"

# %%
def annoying_tool_marshalling(item) -> dict:

    # Lookup how the agent wants to call the tool
    tool_name = item.name
    tool = tool_info[tool_name]
    ToolArgsModel = tool[0]
    tool_fn = tool[2]
    fn_args: ToolArgsModel = ToolArgsModel.model_validate_json(item.arguments)

    # The tool call function itself (ie search)
    # wrapped in something helping with serialization
    py_resp, json_resp = tool_fn(fn_args)

    # 4. Provide function call results to the model
    return {
        "type": "function_call_output",
        "call_id": item.call_id,
        "output": json_resp,
    }


for item in resp.output:
    if item.type == "function_call":
        tool_name = item.name

        # *** Get the tool, and package
        # up the call to the tool (our python function)
        tool_response = annoying_tool_marshalling(item)
        # 4. Provide function call results to the model
        inputs.append(tool_response)
# Out:
# search modern couch geometric sofa clean lines angular

# %% [markdown]
# ## Call LLM again with tool responses
#
# Now we tell the LLM about the tool responses.
#
# It may ask to search more (ie we should continue the loop). Or it may be done and have a final response

# %%
resp = openai.responses.create(
    model="gpt-5",
    input=inputs,
    tools=[tool[1] for tool in tool_info.values()],
)
inputs += resp.output

resp
# Out:
# Response(id='resp_0fb18f3031b8c9620069cdc3879dd881959bf235d96d7033d8', created_at=1775092615.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_0fb18f3031b8c9620069cdc3881ba08195b66b9d1cdba6a6eb', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseFunctionToolCall(arguments='{"keywords":"geometric sofa couch modern angular square arm tufted"}', call_id='call_wTNy2L8tUKDO6Wcx2MpvF4nv', name='search_furniture', type='function_call', id='fc_0fb18f3031b8c9620069cdc38c683081958ee797b4cb8cf1f9', status='completed')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='search_furniture', parameters={'properties': {'keywords': {'title': 'Keywords', 'type': 'string'}}, 'required': ['keywords'], 'title': 'Search_furnitureArgs', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description="Search the available furniture products, get top 10 furniture.\n\n    This is just a naive BM25 / keyword search of the product title and description.\n    Don't expect sophisticated synonyms or semantic search. Just basic keyword with\n    some stemming.")], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=1578, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=310, output_tokens_details=OutputTokensDetails(reasoning_tokens=256), total_tokens=1888), user=None, billing={'payer': 'openai'}, completed_at=1775092620, frequency_penalty=0.0, presence_penalty=0.0, prompt_cache_retention=None, store=True)

# %% [markdown]
# ## Put it all in one loop

# %%
import textwrap

system_prompt = """
Users are coming to explore a catalog of furniture.

Use the search tool (search_furniture) to help them.

Use trial and error to figure out how best use the search tool.
"""

def agentic_search(query: str, summary=True) -> str:

    inputs = []
    inputs.append({"role": "system", "content": system_prompt})

    inputs.append({"role": "user", "content": query})


    tool_calls = True
    resp = None
    while tool_calls:
        resp = openai.responses.create(
            model="gpt-5",
            input=inputs,
            tools=[tool[1] for tool in tool_info.values()],
            reasoning={
                "effort": "medium",
                "summary": "auto" if summary else "none"
            }
        )
        inputs += resp.output
        if summary:
            for item in resp.output:
                if item.type == "reasoning":
                    print("Reasoning:")
                    for summary_item in item.summary:
                        print(textwrap.fill(summary_item.text, 80), "\n")
                    item.summary = []

        for item in resp.output:
            tool_calls = False
            if item.type == "function_call":
                tool_calls = True
                # *** Get the tool, and package
                # up the call to the tool (our python function)
                tool_response = annoying_tool_marshalling(item)

                # 4. Provide function call results to the model
                inputs.append(tool_response)
    return resp

resp = agentic_search("geometric sofa")
# Out:
# Reasoning:
# **Searching for geometric sofas**  The user is looking for a "geometric sofa,"
# so I need to use the search_furniture tool with that exact phrase. The
# instructions tell me to make sure to run the search first and see what I get. If
# there aren’t many results, I can explore some variations afterward, but for now,
# my first step is to call the functions.search_furniture using the keywords
# "geometric sofa." Let’s get started!
#
# search geometric sofa
# Reasoning:
# **Refining search for geometric sofas**  The search results keep showing mostly
# pillows and rugs with geometric patterns, which isn't what I’m looking for
# specifically. Let’s explore alternative queries! I'll try keywords like
# "geometric pattern sofa" or "modern geometric sofa". It seems that "sofa"
# appears in many results due to its common usage, so narrowing it down might be
# tricky without filters. I’ll also consider terms like "geometric couch," since
# that could yield better results. Let's give these a shot!
#
# search geometric couch
# Reasoning:
# **Exploring sofa keywords**  I'm looking at different keywords for more specific
# sofa searches. It seems like I've mostly been finding accessories and couch
# risers rather than geometric sofas. I'll try terms like "angular sofa," "faceted
# sofa," and "sculptural sofa." That said, it feels a bit naive, as I wonder if
# those terms exist. But, it's probably worth trying some options like "geo sofa"
# and "modern sofa geometric pattern" too! Let's see what comes up!
#
# search geometric pattern sofa
# Reasoning:
# **Searching sofa styles**  I’m trying different search terms to find the right
# style for a sofa. I’ll start with "modern sofa angular," then I'll try "angular
# arm sofa," "sculptural sofa," and "geometric lines sofa." I want to capture
# various designs that lean towards angular or geometric features. Each term might
# yield different results, so it's worth exploring all these possibilities. Let's
# see what unique options I can find!
#
# search angular sofa
# Reasoning:
# **Considering patio sofa options**  I'm looking at patio sofas with angular
# designs. The “ferdinand patio sofa” has a tuxedo style, while the “abygayle
# patio sofa” features angular lines. There's also an “88.5'' wide outdoor teak
# patio sofa” that boasts sleek, angular deep seats. They might fit a geometric
# vibe. However, the user requested a "geometric sofa," which seems more suitable
# for indoor use. Maybe I should explore "sculptural sofas" as well.
#
# search sculptural sofa
# Reasoning:
# search geometric sectional
# Reasoning:
# **Searching for sofa styles**  I’m considering how to find a stylish sofa.
# Instead of being too specific, I’ll try broader terms like "geo sofa" or
# "geometric print sofa" to explore more options. This way, I can gather different
# designs that fit what the user might be looking for. It feels like a more
# creative approach, and I’m curious about what the results could be! Let's see
# what I uncover with these new terms!
#
# search geometric print sofa
# Reasoning:
# **Considering sofa searches**  Hmm, the catalog might not directly list
# "geometric sofa" in the title. There could be sofas with geometric patterns in
# the upholstery though. The search tool uses BM25 and covers both titles and
# descriptions, but many options might not contain "geometric." I could ask the
# user for clarification on what they mean—whether they prefer a geometric
# pattern, angular silhouette, or specific colors and materials.  I'll suggest
# some angular patio sofas as alternatives and mention accessorizing a neutral
# sofa with geometric pillows or rugs. Also, I want to show the top relevant
# search results with product details, like ID, title, and a brief description.
#
# **Presenting sofa options**  The user mentioned "geometric sofa," so I can
# showcase 3-5 suitable options. I'll definitely include the angular patio sofas
# and the Holguin convertible sofa, as they're good fits. I could also consider
# tufted channel sofas, but maybe better options would be boxy sofas, square arm
# sofas, or track arm sofas since those all feature geometric lines. It's all
# about finding the right style that resonates with what the user is envisioning!
#
# search square arm sofa
# Reasoning:
# **Curating geometric sofas**  I’m thinking that geometric sofas with square arms
# match the user's interest. They asked for “geometric sofa,” so I should present
# a list of five options.   I found a few models to consider:   - Demars 79''
# Square Arm Sofa - mid-century, stainless frame, faux leather. - Esteves 77.75''
# Square Arm Sofa - a convertible futon with tufting.  - Aleena 79'' Square Arm
# Sofa - mid-century style with button tufting. - Vicki 75'' Square Arm Sofa - a
# contemporary tufted back. - 85'' Faux Leather Square Arm Sofa - mid-century
# design in faux leather.   This should meet the user’s needs!
#
# **Refining sofa options**  I could add the angular outdoor "Ferdinand Patio Sofa
# with Cushions," but perhaps I should focus on indoor options. I also think we
# could include a convertible sofa bed, like the Abilash 83.75'' square arm sofa
# bed, as an alternative.   It might be helpful to ask: “Are you looking for
# geometric pattern upholstery or geometric silhouettes? And what about size,
# color, or budget?”   I plan to suggest square-arm, tuxedo, or track-arm designs
# for geometric lines.   I’ll list the top choices with brief reasons for their
# fit, along with product IDs and descriptions. Then, I'll ask the clarifying
# question at the end.
#
# **Crafting the response**  I’m thinking of starting the response with something
# like, “Here are sofas with clean, geometric lines.” If the user meant geometric
# patterns, I can mention that I could look for those too.   Next, I’ll list 5 to
# 7 items with their titles and a brief highlight for each.   Finally, I should
# ask if they want indoor or outdoor options, and if they prefer a pattern or
# silhouette, as well as their size, color, and budget preferences. There’s no
# need for additional tools at this point; I’ll just move ahead!

# %%
print(resp.output[-1].content[-1].text)
# Out:
# Here are sofas with clean, geometric (square/track-arm, angular) lines that fit a “geometric sofa” look:
#
# - Demars 79" Square Arm Sofa (ID 38889) — Mid-century vibe with a stainless frame and crisp square arms; faux-leather upholstery and foam cushions.
# - Esteves 77.75" Square Arm Convertible Sofa (ID 41468) — Modern square silhouette with tufted back; quickly converts to a bed.
# - Aleena 79" Square Arm Sofa (ID 26318) — Mid-century details, button tufting, tapered legs; multiple fabric options.
# - Vicki 75" Square Arm Sofa (ID 24003) — Contemporary, soft tufted back cushions and a sturdy wood base.
# - 85" Faux Leather Square Arm Sofa (ID 23867) — Streamlined, geometric lines with tapered legs; memory-foam feel and two toss pillows.
# - Abilash 83.75" Square Arm Sofa Bed (ID 3881) — Clean piping and squared feet; pulls out to a twin/single sleeper.
#
# If by “geometric” you meant a bold geometric pattern on the upholstery rather than a boxy silhouette, I can hunt for those too.
#
# Quick preferences to narrow it down:
# - Indoor or outdoor?
# - Silhouette vs. patterned upholstery?
# - Size (width), color/material, and budget range?
