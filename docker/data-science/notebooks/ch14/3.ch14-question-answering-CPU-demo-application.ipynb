# %%
import sys
import html
import pandas
import pickle
import json
import spacy
import warnings
from IPython.core.display import display,HTML
warnings.filterwarnings('ignore') #Some operations warn inside a loop, we'll only need to see the first warning
sys.path.append('..')
from aips import *
outdoors_collection="outdoors"
path = "./"

# %% [markdown]
# ## Listing 13.27

# %%
nlp = spacy.load('en_core_web_lg')
nlp.remove_pipe('ner')
merge_nps = nlp.create_pipe('merge_noun_chunks')
nlp.add_pipe(merge_nps)
determiners = 'all an another any both del each either every half la many much nary neither no some such that the them these this those'.split(' ')
def getQueryFromQuestion(question):
    query = []
    doc = nlp(question)
    for tok in doc:
        if tok.pos_ in ['NOUN','VERB']:
            query.append(tok.text)
    if not len(query):
        query = [question]
    query = ' '.join(query)
    for d in determiners:
        query = query.replace(' '+d+' ','')
    return query

# %%
def retriever(question):
    contexts={"id":[],"question":[],"context":[],"url":[]}
    query = getQueryFromQuestion(question)
    request = {
        "query": query,
        "fields": ["id","url","body"],
        "params": {
          "qf": ["body"],
          "fq": ["post_type_id:2"],
          "defType": "edismax",
          "rows":5
        }
    }
    docs = requests.post(solr_url + outdoors_collection + "/select", json=request).json()["response"]["docs"]
    for doc in docs:
        contexts["id"].append(doc["id"])
        contexts["url"].append(doc["url"])
        contexts["question"].append(question)
        contexts["context"].append(doc["body"])
    return pandas.DataFrame(contexts)

# %%
example_contexts = retriever('What are minimalist shoes?')
example_contexts[0:10]
# Out:
#       id                    question  \
# 0  18376  What are minimalist shoes?
# 1  18370  What are minimalist shoes?
# 2  16427  What are minimalist shoes?
# 3  18375  What are minimalist shoes?
# 4  13540  What are minimalist shoes?
#
#                                              context  \
# 0  Minimalist shoes or "barefoot" shoes are shoes...
# 1  There was actually a project done on the defin...
# 2  One summer job, I needed shoes to walk on a ro...
# 3  The answer to this question will vary on your ...
# 4  Barefoot Shoes Also known as minimalist shoes,...
#
#                                                  url
# 0  https://outdoors.stackexchange.com/questions/1...
# 1  https://outdoors.stackexchange.com/questions/1...
# 2  https://outdoors.stackexchange.com/questions/1...
# 3  https://outdoors.stackexchange.com/questions/1...
# 4  https://outdoors.stackexchange.com/questions/1...

# %% [markdown]
# ## Listing 14.28

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
import tqdm

# Our pretrained model!
model_name = './data/roberta-base-squad2-outdoors'

device=-1 #CPU
#device=0 #<-- Uncomment to use GPU, if you are running in Google Colab

qa_nlp = pipeline('question-answering', model=model_name, tokenizer=model_name, device=device)

def reader(question):
    answers = []
    contexts = getCandidateContexts(question)
    for idx,row in tqdm.tqdm(contexts.iterrows(),total=len(contexts)):
        result = qa_nlp({"question":row["question"],"context":row["context"]})
        result["id"] = row["id"]
        result["url"] = row["url"]
        answers.append(result)
    return answers
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at ./data/roberta-base-squad2-outdoors and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Listing 14.28

# %%
def reranker(answers):
    sorted_answers = sorted(answers, key=lambda k: k['score'], reverse=True)
    return sorted_answers

# %% [markdown]
# ## Listing 13.29

# %%
import urllib.parse
def ask(question):
    documents = retriever(quertion)
    answers = reader(documents)
    reranked = reranker(answers)
    
    stackexchange_search_url = 'https://outdoors.stackexchange.com/search?q='+urllib.parse.quote(question)
    display(HTML('<h1><a href="'+stackexchange_search_url+'" target=_blank>'+question+'</a></h1>'))
    for answer in reranked:
        display(HTML('<a href="'+answer["url"]+'" target=_blank>'+answer["id"]+'</a>&nbsp;<strong>'+answer["answer"]+'</strong><em>('+str(answer["score"])+')</em>'))

# %%
ask('What is the best mosquito repellant?')
# Out:
# 100%|██████████| 5/5 [00:04<00:00,  1.15it/s]
# <h1><a href="https://outdoors.stackexchange.com/search?q=What%20is%20the%20best%20mosquito%20repellant%3F" target=_blank>What is the best mosquito repellant?</a></h1>
# <a href="https://outdoors.stackexchange.com/questions/13287" target=_blank>13287</a>&nbsp;<strong>DEET</strong><em>(0.8438088297843933)</em>
# <a href="https://outdoors.stackexchange.com/questions/16459" target=_blank>16459</a>&nbsp;<strong>Screens</strong><em>(0.8082907795906067)</em>
# <a href="https://outdoors.stackexchange.com/questions/19647" target=_blank>19647</a>&nbsp;<strong>DEET</strong><em>(0.391293466091156)</em>
# <a href="https://outdoors.stackexchange.com/questions/7724" target=_blank>7724</a>&nbsp;<strong>Gore-Tex</strong><em>(0.3498077690601349)</em>
# <a href="https://outdoors.stackexchange.com/questions/1698" target=_blank>1698</a>&nbsp;<strong>wasp-repellant and sunscreen</strong><em>(0.14082129299640656)</em>

# %%
ask('What is the best waterproof boot?')
# Out:
# 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# <h1><a href="https://outdoors.stackexchange.com/search?q=What%20is%20the%20best%20waterproof%20boot%3F" target=_blank>What is the best waterproof boot?</a></h1>
# <a href="https://outdoors.stackexchange.com/questions/7945" target=_blank>7945</a>&nbsp;<strong>Goretex</strong><em>(0.4660898447036743)</em>
# <a href="https://outdoors.stackexchange.com/questions/5281" target=_blank>5281</a>&nbsp;<strong>Gore-Tex walking boots?</strong><em>(0.28801077604293823)</em>
# <a href="https://outdoors.stackexchange.com/questions/6817" target=_blank>6817</a>&nbsp;<strong>Sno-Seal</strong><em>(0.07046116143465042)</em>
# <a href="https://outdoors.stackexchange.com/questions/8850" target=_blank>8850</a>&nbsp;<strong>a studier boot</strong><em>(0.057546619325876236)</em>
# <a href="https://outdoors.stackexchange.com/questions/8588" target=_blank>8588</a>&nbsp;<strong>Lighter, thinner material boots</strong><em>(0.028219878673553467)</em>

# %%
ask('How many people fit inside a two-person tent?')
# Out:
# 100%|██████████| 5/5 [00:04<00:00,  1.12it/s]
# <h1><a href="https://outdoors.stackexchange.com/search?q=How%20many%20people%20fit%20inside%20a%20two-person%20tent%3F" target=_blank>How many people fit inside a two-person tent?</a></h1>
# <a href="https://outdoors.stackexchange.com/questions/24593" target=_blank>24593</a>&nbsp;<strong>1</strong><em>(0.7559880018234253)</em>
# <a href="https://outdoors.stackexchange.com/questions/10225" target=_blank>10225</a>&nbsp;<strong>1.</strong><em>(0.30376508831977844)</em>
# <a href="https://outdoors.stackexchange.com/questions/20803" target=_blank>20803</a>&nbsp;<strong>2-3</strong><em>(0.20367492735385895)</em>
# <a href="https://outdoors.stackexchange.com/questions/5927" target=_blank>5927</a>&nbsp;<strong>two</strong><em>(0.05628575384616852)</em>
# <a href="https://outdoors.stackexchange.com/questions/8791" target=_blank>8791</a>&nbsp;<strong>two people</strong><em>(0.020044146105647087)</em>

# %%
ask('What hiking boots work with crampons?')
# Out:
# 100%|██████████| 5/5 [00:09<00:00,  1.85s/it]
# <h1><a href="https://outdoors.stackexchange.com/search?q=What%20hiking%20boots%20work%20with%20crampons%3F" target=_blank>What hiking boots work with crampons?</a></h1>
# <a href="https://outdoors.stackexchange.com/questions/22119" target=_blank>22119</a>&nbsp;<strong>Mountaineering boots</strong><em>(0.6972461342811584)</em>
# <a href="https://outdoors.stackexchange.com/questions/5054" target=_blank>5054</a>&nbsp;<strong>Grivel G-12's,</strong><em>(0.6121198534965515)</em>
# <a href="https://outdoors.stackexchange.com/questions/11602" target=_blank>11602</a>&nbsp;<strong>Scarpa B2 winter boots</strong><em>(0.24318985641002655)</em>
# <a href="https://outdoors.stackexchange.com/questions/214" target=_blank>214</a>&nbsp;<strong>they're pretty universal.</strong><em>(0.09049165993928909)</em>
# <a href="https://outdoors.stackexchange.com/questions/10296" target=_blank>10296</a>&nbsp;<strong>Most hiking boots do not have any welts,</strong><em>(0.08273779600858688)</em>

# %%
ask('How far can one person hike in one day?')
# Out:
# 100%|██████████| 5/5 [00:09<00:00,  1.86s/it]
# <h1><a href="https://outdoors.stackexchange.com/search?q=How%20far%20can%20one%20person%20hike%20in%20one%20day%3F" target=_blank>How far can one person hike in one day?</a></h1>
# <a href="https://outdoors.stackexchange.com/questions/1629" target=_blank>1629</a>&nbsp;<strong>3 liters per person per day.</strong><em>(0.5262552499771118)</em>
# <a href="https://outdoors.stackexchange.com/questions/3723" target=_blank>3723</a>&nbsp;<strong>2½ hour</strong><em>(0.3544653654098511)</em>
# <a href="https://outdoors.stackexchange.com/questions/8810" target=_blank>8810</a>&nbsp;<strong>4-day</strong><em>(0.29578590393066406)</em>
# <a href="https://outdoors.stackexchange.com/questions/19609" target=_blank>19609</a>&nbsp;<strong>12 miles</strong><em>(0.038266751915216446)</em>
# <a href="https://outdoors.stackexchange.com/questions/6790" target=_blank>6790</a>&nbsp;<strong>multi-day</strong><em>(0.011345484293997288)</em>

# %%
ask('How much water does a person need each day?')
# Out:
# 100%|██████████| 5/5 [00:07<00:00,  1.60s/it]
# <h1><a href="https://outdoors.stackexchange.com/search?q=How%20much%20water%20does%20a%20person%20need%20each%20day%3F" target=_blank>How much water does a person need each day?</a></h1>
# <a href="https://outdoors.stackexchange.com/questions/1629" target=_blank>1629</a>&nbsp;<strong>3 liters</strong><em>(0.4088960587978363)</em>
# <a href="https://outdoors.stackexchange.com/questions/20766" target=_blank>20766</a>&nbsp;<strong>6 quarts per day.</strong><em>(0.21337765455245972)</em>
# <a href="https://outdoors.stackexchange.com/questions/17918" target=_blank>17918</a>&nbsp;<strong>~55 min</strong><em>(0.012813975103199482)</em>
# <a href="https://outdoors.stackexchange.com/questions/8810" target=_blank>8810</a>&nbsp;<strong>won't need much.</strong><em>(0.00865719560533762)</em>
# <a href="https://outdoors.stackexchange.com/questions/19899" target=_blank>19899</a>&nbsp;<strong>34.4 °C (93.9 °F).</strong><em>(0.004292960278689861)</em>

# %%
ask('What materials make good walking poles?')
# Out:
# 100%|██████████| 5/5 [00:09<00:00,  1.86s/it]
# <h1><a href="https://outdoors.stackexchange.com/search?q=What%20materials%20make%20good%20walking%20poles%3F" target=_blank>What materials make good walking poles?</a></h1>
# <a href="https://outdoors.stackexchange.com/questions/5315" target=_blank>5315</a>&nbsp;<strong>BlackDiamond</strong><em>(0.5954394936561584)</em>
# <a href="https://outdoors.stackexchange.com/questions/11919" target=_blank>11919</a>&nbsp;<strong>tarp supports</strong><em>(0.38886240124702454)</em>
# <a href="https://outdoors.stackexchange.com/questions/14112" target=_blank>14112</a>&nbsp;<strong>aluminium and carbon fibre</strong><em>(0.2754027247428894)</em>
# <a href="https://outdoors.stackexchange.com/questions/14528" target=_blank>14528</a>&nbsp;<strong>train with poles.</strong><em>(0.057332705706357956)</em>
# <a href="https://outdoors.stackexchange.com/questions/4477" target=_blank>4477</a>&nbsp;<strong>"Trekking poles</strong><em>(0.03563595190644264)</em>
