# %% [markdown]
# # Personalized Search

# %% [markdown]
# **NOTE**: This notebook depends upon the the Retrotech dataset. If you have any issues, please rerun the [Setting up the Retrotech Dataset](../ch4/1.ch4-setting-up-the-retrotech-dataset.ipynb) notebook.

# %%
import sys
sys.path.append('..')
from aips import *
import os
from IPython.display import display,HTML
from pyspark.sql import SparkSession

# %%
#Recommended for making ALS run faster, if you have enough memory / cores allocated to docker
from pyspark.conf import SparkConf
conf = SparkConf()
conf.set("spark.driver.memory", '8g')
#conf.set("spark.executor.cores", "6")
conf.set("spark.dynamicAllocation.enabled", "true")
#conf.set("spark.executor.memory", "11g")
#conf.set("spark.dynamicAllocation.executorMemoryOverhead", "11g")
#conf.set("spark.driver.memory", "11g")
spark = SparkSession.builder.appName("aips-ch9").config(conf=conf).getOrCreate()

# %%
### Load product data
from pyspark.sql.types import LongType, StringType, StructField, StructType, BooleanType, ArrayType, IntegerType
products_collection = "products"    
product_update_opts={"zkhost": "aips-zk", "collection": products_collection}
spark.read.format("solr").options(**product_update_opts).load().createOrReplaceTempView("products")

# %% [markdown]
# # Collaborative Filtering with Implicit Preferences

# %%
def aggregate_signals(signals_collection, signals_aggregation_collection, signals_aggregation_query):

    create_collection(signals_aggregation_collection)

    print("Aggregating Signals to Create Signals Boosts...")
    signals_opts={"zkhost": "aips-zk", "collection": signals_collection}
    signals_boosting_opts={"zkhost": "aips-zk", "collection": signals_aggregation_collection, "gen_uniq_key": "true", "commit_within": "5000"}
    df = spark.read.format("solr").options(**signals_opts).load()
    df.createOrReplaceTempView("signals")


    spark.sql(signals_aggregation_query).write.format("solr").options(**signals_boosting_opts).mode("overwrite").save()
    print("Signals Aggregation Completed!")

# %% [markdown]
# ## Listing 9.1

# %%
#Weighting multiple signal types by user
click_weight = 1
add_to_cart_weight = 0 #increase (i.e. to 10) to consider add to cart signals
purchase_weight = 0 #increase (i.e. to 25) to consider purchase signals

signals_collection="signals"
signals_aggregation_collection="user_product_implicit_preferences"

mixed_signal_types_aggregation = """
select user, product, (
      (1 * click_boost) 
    + (10 * add_to_cart_boost) 
    + (25 * purchase_boost) ) as rating
from (
  select user, product, 
    sum(click) as click_boost,
    sum(add_to_cart) as add_to_cart_boost,
    sum(purchase) as purchase_boost
  from (  
      select cap.user, cap.target as product, 
        if(cap.type = 'click', """f"{click_weight}"""", 0) as click, 
        if(cap.type = 'add-to-cart', """f"{add_to_cart_weight}"""", 0) as  add_to_cart, 
        if(cap.type = 'purchase', """f"{purchase_weight}"""", 0) as purchase
      from signals cap 
      where (cap.type != 'query')
    ) raw_signals
  group by user, product
) as per_type_boosts
"""

aggregate_signals(signals_collection, signals_aggregation_collection, mixed_signal_types_aggregation)
# Out:
# Wiping 'user_product_implicit_preferences' collection
# [('action', 'CREATE'), ('name', 'user_product_implicit_preferences'), ('numShards', 1), ('replicationFactor', 1)]
# Creating 'user_product_implicit_preferences' collection
# Status: Success
# Aggregating Signals to Create Signals Boosts...
# Signals Aggregation Completed!

# %%
user_prefs_options={"zkhost": "aips-zk", "collection": signals_aggregation_collection}
df = spark.read.format("solr").options(**user_prefs_options).load()
df.createOrReplaceTempView("user_product_implicit_preferences")

# %% [markdown]
# ### TODO: verify the above table is fully written before proceeding. Need to ensure downstream issues don't occur (i.e. userIndexer.fit / productIndexer.fit method training on empty data.)

# %% [markdown]
# ## Listing 9.2

# %%
##50K = all products
#This will take long time. Recommend setting to 1,000 if trying to just run through code
#without considering all products

top_product_count_for_recs = 50000 #all products. 

user_item_ratings = spark.sql(f"""
  select user, product, rating from user_product_implicit_preferences
  where product in (
    select product from (
      select product, count(user) user_count from user_product_implicit_preferences
      group by product
      order by user_count desc
      limit {top_product_count_for_recs}
    ) top_products
  )   
  order by rating desc""")

# %% [markdown]
# ## Listing 9.3

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import IndexToString

userIndexer = StringIndexer(inputCol="user", outputCol="userIndex").fit(user_item_ratings)
productIndexer = StringIndexer(inputCol="product", outputCol="productIndex").fit(user_item_ratings)

def stringsToIndexes(user_item_ratings,user_indexer,product_indexer):
    #Fits a model to the input dataset with optional parameters.
    return product_indexer.transform(user_indexer.transform(user_item_ratings))
    
def indexesToStrings(user_item_ratings,user_indexer,product_indexer):
    userIndexToString = IndexToString(inputCol="userIndex", outputCol="user",
                                    labels=user_indexer.labels)
    
    productIndexToString = IndexToString(inputCol="productIndex", outputCol="product",
                                    labels=product_indexer.labels)

    return userIndexToString.transform(productIndexToString.transform(user_item_ratings))

# %%
from pyspark.sql.functions import col
indexedUserPrefs = stringsToIndexes(user_item_ratings,userIndexer,productIndexer)
indexedUserPrefs.orderBy(col("userIndex").asc(),col("rating").desc()).show(10)
# Out:
# +-------+------------+------+---------+------------+
# |   user|     product|rating|userIndex|productIndex|
# +-------+------------+------+---------+------------+
# |u159789|085391163121|     1|      0.0|      9196.0|
# |u159789|886541105851|     1|      0.0|      1394.0|
# |u159789|025193102324|     1|      0.0|      9650.0|
# |u159789|886112115302|     1|      0.0|       548.0|
# |u159789|008888345435|     1|      0.0|      5073.0|
# |u159789|014633196870|     1|      0.0|      4525.0|
# |u159789|720616236029|     1|      0.0|      2781.0|
# |u159789|024543718710|     1|      0.0|       263.0|
# |u159789|813985010007|     1|      0.0|      5819.0|
# |u159789|801213001996|     1|      0.0|     28736.0|
# +-------+------------+------+---------+------------+
# only showing top 10 rows

# %% [markdown]
# ## Listing 9.4

# %%
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.sql import Row

als = ALS(maxIter=3, rank=10, regParam=0.15, implicitPrefs=True, userCol="userIndex", itemCol="productIndex", ratingCol="rating", coldStartStrategy="drop", seed=0)
#-3939200230093063679

(training, test) = indexedUserPrefs.randomSplit([0.8, 0.2], 0)

print("Beginning model training")
model = als.fit(indexedUserPrefs)

print("Beginning predictions")
predictions = model.transform(test)

print("Beginning evaluation")
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# Beginning model training
# Beginning predictions
# Beginning evaluation
# Root-mean-square error = 0.9589328844781423

# %% [markdown]
# ## Listing 9.5

# %%
# Generate top 3 product recommendations for each user
indexedUserRecs = model.recommendForAllUsers(10)
indexedUserRecs.show(5)
#print(predictions.orderBy(col("userIndex").asc(),col("prediction").desc()))
# Out:
# +---------+--------------------+
# |userIndex|     recommendations|
# +---------+--------------------+
# |       26|[{17, 0.037616048...|
# |       27|[{17, 0.001811180...|
# |       28|[{30, 0.06910295}...|
# |       31|[{13, 0.008291349...|
# |       34|[{14, 0.005998417...|
# +---------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## Listing 9.6

# %%
from pyspark.sql.functions import explode, col

exploded = (indexedUserRecs.select("userIndex", explode("recommendations").alias("productIndex_rating"))).select("userIndex", col("productIndex_rating.*"))
userItemRecs = indexesToStrings(exploded,userIndexer,productIndexer).select("user", "product", col("rating").alias("boost"))

# %% [markdown]
# # Listing 9.7

# %%
import datetime 
print ("Start Time: " + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

#Write recommendations to Solr
def write_boosts_signals(recommendations_collection, userItemRecs):

    create_collection(recommendations_collection)

    print("Writing recommendations to Solr...")
    signals_opts={"zkhost": "aips-zk", "collection": recommendations_collection}
    opts={"zkhost": "aips-zk", "collection": recommendations_collection, 
          "gen_uniq_key": "true", "commit_within": "5000"}
    userItemRecs.createOrReplaceTempView("temp_user_item_recs") #faster to use spark.sql than write df directly due to execution plan
    spark.sql("select * from temp_user_item_recs"
             ).write.format("solr").options(**opts).mode("overwrite").save()
    #userItemRecs.write.format("solr").options(**opts).mode("overwrite").save()
    print("Recommendations saved to table: " + recommendations_collection)
    
write_boosts_signals("user_item_recommendations", userItemRecs)

print ("End Time: " + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Start Time: 2023-10-26 21:13:55
# Wiping 'user_item_recommendations' collection
# [('action', 'CREATE'), ('name', 'user_item_recommendations'), ('numShards', 1), ('replicationFactor', 1)]
# Creating 'user_item_recommendations' collection
# Status: Success
# Writing recommendations to Solr...
# Recommendations saved to table: user_item_recommendations
# End Time: 2023-10-26 21:20:37

# %% [markdown]
# # Search with Recommendations Boosts
# Whereas signals boosting boosts the most popular documents for a particular query (ch8), you can also boost the most personalized items for a particular user. In order to serve up the pre-generated collaborative recommendations we just generated, we can just need to run a search and boost the recommended items for each user.

# %% [markdown]
# ## Listing 9.8

# %%
def search(collection="products", query="*:*", user="", 
           filters=[], sort="", fields=["*"], params={}):
    return requests.post(
             f"{SOLR_URL}/{collection}/select", json={
               "query":query, "filter": filters, "sort": sort, 
               "fields": fields, "params": params}
           ).json()["response"]


user = "u478462" #example user
signals_collection = "signals"

previous_searches = search(collection=signals_collection, 
                           filters=["user:" + user, "type:query"], 
                           sort="signal_time asc")["docs"]

product_interactions = search(
                                collection=signals_collection, 
                                filters=["user:" + user, "-type:query"], 
                                sort="signal_time asc")["docs"]

interacted_products = ""
for interaction in product_interactions:
    if len(interacted_products) > 0: interacted_products += " "
    interacted_products += interaction["target"]

product_search = search(
                    filters=["upc:(" + interacted_products + ")"]
                 )["docs"]
product_info = {}
for product in product_search:
    product_info[product["upc"]] = product["name"]\
        .replace("&#xAE;","®").replace("&#x2122;", "™") #replace encoded version to make more readable


print("User: " + str(user))
    
print("\nPrevious Searches: ")
for doc in previous_searches:
    print("--" + doc["target"])
    
print("\nPrevious Product Interactions: ")
for interaction in product_interactions:
    print("--type: " + interaction["type"] + ", name: " 
                     + product_info[interaction["target"]])
# Out:
# User: u478462
#
# Previous Searches:
# --apple
# --macbook
#
# Previous Product Interactions:
# --type: click, name: Apple® - iPad® 2 with Wi-Fi - 16GB - Black
# --type: add-to-cart, name: Apple® - iPad® 2 with Wi-Fi - 16GB - Black
# --type: purchase, name: Apple® - iPad® 2 with Wi-Fi - 16GB - Black
# --type: click, name: Apple® - MacBook® Air - Intel® Core™ i5 Processor - 11.6" Display - 4GB Memory - 128GB Flash Storage

# %% [markdown]
# ## Listing 9.9

# %%
user = "u478462"
user_item_recs_collection = "user_item_recommendations"

def get_query_time_boosts(user, boosts_collection):
    user_filter = ["user:" + user] if user else []

    signals_boosts = search(
            boosts_collection, filters=user_filter, sort="boost desc", 
            fields = ["product", "boost"], params={"rows": 10}
        )["docs"]

    product_boosts = ""
    for entry in signals_boosts:
        if len(product_boosts) > 0:  product_boosts += " "
        product_boosts += '"' + str(entry['product']) \
                              + '"^' + str(float(entry['boost'])*100)

    return product_boosts

def run_main_query(query, signals_boosts, rows=5):     
    if not signals_boosts: signals_boosts = "*:*"
    if not query: query="*:*"
        
    main_query = search(
        query=query, fields=["upc", "name", "manufacturer", "score", "shortDescription"],
        sort="score desc, upc asc", params={
          "qf": "name manufacturer longDescription", 
          "defType": "edismax", "rows": rows,
          "boost": "sum(1,query({! df=upc v=$signals_boosting}))",
          "signals_boosting": signals_boosts
        })    
    
    return main_query

recommendations_boosts = get_query_time_boosts(user, "user_item_recommendations")
print("Boost Query:\n" + recommendations_boosts)

#recommendations
search_results = run_main_query(query=None, signals_boosts=recommendations_boosts, rows=6)["docs"]
print("\nRecommendations: ")
display(HTML(render_search_results("", search_results)))
# Out:
# Boost Query:
# "885909457588"^75.393623 "097360810042"^18.904798 "821793013776"^15.852094 "610839379408"^10.217768000000001 "635753493559"^9.087185 "885909395095"^8.304988 "885909457595"^7.9175640000000005 "885909431618"^7.375394 "885909459858"^6.592548 "885909436002"^6.1031554
#
# Recommendations:
# <div id="demo">
#         <input style="width:50%" readonly type="text" name="q" value="">
#         <input readonly type="submit" value="Search">
#
#     <div class="results">
#
#
#     </div>
# </div>
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/885909457588.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Apple&#xAE; - iPad&#xAE; 2 with Wi-Fi - 16GB - Black | <strong>Manufacturer:</strong> Apple&#xAE;</p>
# 	    		<p>9.7" widescreen display; 802.11a/b/g/n Wi-Fi; Bluetooth; iBooks support; measures just 0.34" thin and weighs only 1.35 lbs.
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/821793013776.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> HTC - Flyer Tablet with 16GB Internal Memory - White | <strong>Manufacturer:</strong> HTC</p>
# 	    		<p>Android 2.3 Gingerbread operating system7" color touch screenWi-Fi16GB memoryHTC notes, Watch and Listen apps
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/610839379408.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Asus - Eee Pad Transformer Tablet with 16GB Storage Memory - Brown/Black | <strong>Manufacturer:</strong> Asus</p>
# 	    		<p>Android 3.0 Honeycomb10.1" WXGA IPS touch screen Wi-Fi16GB hard drive
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/635753493559.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Samsung - Galaxy Tab 10.1 - 16GB - Metallic Gray | <strong>Manufacturer:</strong> Samsung</p>
# 	    		<p>Android 3.1 (Honeycomb) operating system10.1" WXGA touch screenWi-Fi
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/885909395095.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Apple&#xAE; - iPod touch&#xAE; 32GB* MP3 Player (4th Generation - Latest Model) - Black | <strong>Manufacturer:</strong> Apple&#xAE;</p>
# 	    		<p>FaceTime camera, HD video recording, Retina display, Multi-Touch interface; gorgeous 3.5" widescreen display; Wi-Fi Web browsing
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/885909457595.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Apple&#xAE; - iPad&#xAE; 2 with Wi-Fi - 32GB - Black | <strong>Manufacturer:</strong> Apple&#xAE;</p>
# 	    		<p>9.7" widescreen display; 802.11a/b/g/n Wi-Fi; Bluetooth; iBooks support
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>

# %% [markdown]
# ## Listing 9.10

# %%
#non-personalized query
query="tablet"
search_results = run_main_query(query=query, signals_boosts=None, rows=4)["docs"]
print(f"Non-personalized Query (q={query}): ")
display(HTML(render_search_results(query, search_results)))
# Out:
# Non-personalized Query (q=tablet):
# <div id="demo">
#         <input style="width:50%" readonly type="text" name="q" value="tablet">
#         <input readonly type="submit" value="Search">
#
#     <div class="results">
#
#
#     </div>
# </div>
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/600603138423.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Init&#x2122; - Tablet Sleeve - Olive | <strong>Manufacturer:</strong> Init&#x99;</p>
# 	    		<p>Fits most tablets with up to a 10" display; heavy-duty neoprene material
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/5024545249224.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Memorial Tablet - CD | <strong>Manufacturer:</strong> Ltm/cd41</p>
# 	    		<p>\N
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/793447512228.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Stone Tablet - CD | <strong>Manufacturer:</strong> Important Records</p>
# 	    		<p>\N
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/27242831599.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Sony - AC Power Adapter for Sony Tablet S | <strong>Manufacturer:</strong> Sony</p>
# 	    		<p>Compatible with Sony Tablet S; charges your tablet
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>

# %%
#personalized query
search_results = run_main_query(query=query, signals_boosts=recommendations_boosts, rows=7)["docs"]
print(f"Personalized Query (q={query}, user={user}): ")
display(HTML(render_search_results(query, search_results)))
# Out:
# Personalized Query (q=tablet, user=u478462):
# <div id="demo">
#         <input style="width:50%" readonly type="text" name="q" value="tablet">
#         <input readonly type="submit" value="Search">
#
#     <div class="results">
#
#
#     </div>
# </div>
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/885909457588.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Apple&#xAE; - iPad&#xAE; 2 with Wi-Fi - 16GB - Black | <strong>Manufacturer:</strong> Apple&#xAE;</p>
# 	    		<p>9.7" widescreen display; 802.11a/b/g/n Wi-Fi; Bluetooth; iBooks support; measures just 0.34" thin and weighs only 1.35 lbs.
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/821793013776.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> HTC - Flyer Tablet with 16GB Internal Memory - White | <strong>Manufacturer:</strong> HTC</p>
# 	    		<p>Android 2.3 Gingerbread operating system7" color touch screenWi-Fi16GB memoryHTC notes, Watch and Listen apps
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/610839379408.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Asus - Eee Pad Transformer Tablet with 16GB Storage Memory - Brown/Black | <strong>Manufacturer:</strong> Asus</p>
# 	    		<p>Android 3.0 Honeycomb10.1" WXGA IPS touch screen Wi-Fi16GB hard drive
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/635753493559.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Samsung - Galaxy Tab 10.1 - 16GB - Metallic Gray | <strong>Manufacturer:</strong> Samsung</p>
# 	    		<p>Android 3.1 (Honeycomb) operating system10.1" WXGA touch screenWi-Fi
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/885909457595.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Apple&#xAE; - iPad&#xAE; 2 with Wi-Fi - 32GB - Black | <strong>Manufacturer:</strong> Apple&#xAE;</p>
# 	    		<p>9.7" widescreen display; 802.11a/b/g/n Wi-Fi; Bluetooth; iBooks support
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/600603138423.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Init&#x2122; - Tablet Sleeve - Olive | <strong>Manufacturer:</strong> Init&#x99;</p>
# 	    		<p>Fits most tablets with up to a 10" display; heavy-duty neoprene material
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/5024545249224.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Memorial Tablet - CD | <strong>Manufacturer:</strong> Ltm/cd41</p>
# 	    		<p>\N
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>

# %% [markdown]
# # Vector-based Personalization

# %%
spark.sql("""select count(upc), count(distinct upc),count(name), count(distinct name), count(distinct shortDescription) from products g""").show(2)
# Out:
# +----------+-------------------+-----------+--------------------+--------------------------------+
# |count(upc)|count(DISTINCT upc)|count(name)|count(DISTINCT name)|count(DISTINCT shortDescription)|
# +----------+-------------------+-----------+--------------------+--------------------------------+
# |     48194|              46155|      48194|               46124|                           19024|
# +----------+-------------------+-----------+--------------------+--------------------------------+

# %% [markdown]
# ## Listing 9.11

# %%
### Create the product data set for embeddings 
product_dataframe=spark.sql("""
  select distinct name, string(upc), shortDescription, 
  concat(name," ",shortDescription ) as name_desc from products""")
product_dataframe.createOrReplaceTempView("products_samples")
#product_texts=product_dataframe.select("name_desc").rdd.flatMap(lambda x: x).collect()
product_names=product_dataframe.select("name").rdd.flatMap(lambda x: x).collect()
product_ids=product_dataframe.select("upc").rdd.flatMap(lambda x: x).collect()

# %%
len(product_ids),len(product_names)
# Out:
# (48164, 48164)

# %%
from sentence_transformers import SentenceTransformer
transformer = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# %% [markdown]
# ## Listing 9.12

# %%
### Get the embedding 
import pickle, os
from sentence_transformers import SentenceTransformer
## picked this model "all-mpnet-base-v2" based on benchmark on this link https://medium.com/@nils_reimers/openai-gpt-3-text-embeddings-really-a-new-state-of-the-art-in-dense-text-embeddings-6571fe3ec9d9
transformer = SentenceTransformer('all-mpnet-base-v2')
embFileName='../data/product_data_embeddings_all-mpnet-base-v2_names_all_embed.pickle'
dataFileName= '../data/product_data_embeddings_all-mpnet-base-v2_names_all_names.pickle'
iDsFileName= '../data/product_data_embeddings_all-mpnet-base-v2_names_all_ids.pickle'

###
def getEmbeddings(texts,ids,ignore_cache=False):
    load_from_cache=True
    
    if ignore_cache or not (os.path.isfile(embFileName) and os.path.isfile(dataFileName) and os.path.isfile(iDsFileName)):
        load_from_cache=False  
        
    if not load_from_cache:
        embeddings = transformer.encode(texts, convert_to_tensor=False)
        with open(embFileName,'wb') as fd:
            pickle.dump(embeddings,fd)
        with open(dataFileName,'wb') as fd:
            pickle.dump(texts,fd)
        with open(iDsFileName,'wb') as fd:
            pickle.dump(ids,fd)
    else:
        with open(embFileName,'rb') as fd:
            embeddings = pickle.load(fd)
        with open(dataFileName,'rb') as fd:
            texts = pickle.load(fd)
        with open(iDsFileName,'rb') as fd:
            ids = pickle.load(fd)
    return embeddings,texts,ids

# %%
#product_embeddings=getEmbeddings(p_texts,load_from_cache=True)
#product_embeddings=getEmbeddings(product_names,load_from_cache=True)

product_embeddings,product_names,product_ids=getEmbeddings(product_names,product_ids)

# %%
### Product Ids-embedding, Product ID-names dictionaries 
product_ids_emb = dict(zip(product_ids, product_embeddings))
product_ids_names= dict(zip(product_ids, product_names))
#len(product_texts), len(product_embeddings), len(product_names) ,len(product_ids),len(product_ids_names.values())
len(product_embeddings), len(product_names) ,len(product_ids),len(product_ids_names.values())
# Out:
# (48164, 48164, 48164, 46155)

# %%
######## Cluster the product info
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.cluster as cluster
import time

# %% [markdown]
# ## Listing 9.13

# %%
## Get the clusters 
def get_clusters(data, algorithm, args, kwds):
    start_time = time.time()
    algo=algorithm(*args, **kwds).fit(data)
    end_time = time.time()
    return algo

# %%
### K-means clustering
algo=get_clusters(product_embeddings, cluster.KMeans, (), {'n_clusters':100, 'n_init':10, 'random_state':0})
labels = algo.predict(product_embeddings)
centers=algo.cluster_centers_

# %%
def assign_clusters(labels,product_names):
    clusters={}
    clusters = defaultdict(lambda:[],clusters)
    for l in range(0,len(labels)):
        clusters[labels[l]].append(product_names[l])
    return clusters

# %%
clusters=assign_clusters(labels,product_names)

# %%
#from sklearn.manifold import TSNE
#X = np.array(centers, dtype=np.float32)
#X.shape
#tsne = TSNE(random_state=0, n_iter=1000)
#tsne_results = tsne.fit_transform(X)
#df_tsne = pd.DataFrame(tsne_results, columns=['TSNE1', 'TSNE2'])
#df_tsne['Cluster'] = clusters.keys()
#fig, ax = plt.subplots(figsize=(8,6)) # Set figsize
#sns.set_style('darkgrid', {"grid.color": "0.6", "grid.linestyle": ":"})
#sns.scatterplot(data=df_tsne, x='TSNE1', y='TSNE2', hue='Cluster', palette='magma')
#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
#plt.title('Scatter plot of products using KMeans Clustering');
#plt.xlabel('TSNE1');
#plt.ylabel('TSNE2');
#plt.axis('equal')

# %% [markdown]
# ## Listing 9.14

# %%
import collections, itertools
from sklearn.decomposition import PCA

stopwords = ['in', 'for', 'with', 'of', 'the', "to", "and"]

def top_words(clusters, top_n):
    # Loop through the clusters and split each string on space
    tokenized = [cluster.split() for cluster in clusters]
    
    # Flatten the list of lists
    flattened = list(itertools.chain.from_iterable(tokenized))
    
    filtered = [word for word in flattened if len(word) > 1 and word.lower() not in stopwords]
    
    # Return the most common words
    return [ word for word, count in collections.Counter(filtered).most_common(top_n) ]

#Importing required modules

from adjustText import adjust_text
import numpy as np
import matplotlib.pyplot as plt
 
data = centers
pca = PCA(100, svd_solver="full")
 
#Transform the data for 2-D visualization

plt.figure(figsize=(15,15))

plot_data = pca.fit_transform(centers)
#plot_data = centers
#plt.scatter(plot_data[:,0] , plot_data[:,1] , s = 30, color = 'k')

text_labels = []
for i, cluster_name in enumerate(plot_data):
    plt.scatter(plot_data[i,0] , plot_data[i,1] , s = 30, color = 'k') 
    text_labels.append(plt.text(plot_data[i,0], 
                                plot_data[i,1],str(i) + "_" +"_".join(top_words(clusters[i],2)), fontsize=12))
adjust_text(text_labels, arrowprops=dict(arrowstyle='-', color='gray', alpha=.3))
# Out:
# 81

# %%
clusters[1]  #useful for spot checking clusters to ensure items inside are homogenous
# Out:
# ['Music Pro Guides: Logic Pro 7 - Advanced Level - DVD',
#  'Elite - DVD',
#  'Fagbug - DVD',
#  'MI-5, Vol. 1 [3 Discs] - DVD',
#  'Masked and Anonymous - (Ws Sub Ac3 Dol) - DVD',
#  'Tool: Schism - DVD',
#  'Help! - DVD',
#  'Inside Genesis: A Critical Review - 1975-1980 - Dts - DVD',
#  'Mandingo - DVD',
#  'Evangelion 2.0: You Can (Not) Advance - DVD',
#  '35 Rhums - DVD',
#  'Renovation Nation: Recycle Reuse & Reclaim - DVD',
#  'The Ultimate Physics Tutor - Fullscreen - DVD',
#  'Sony - 60-Minute MiniDV Digital Video Cassettes (6-Pack)',
#  'Soca Gold 2009 [CD & DVD] - Various CD+DVD - CD',
#  'Gidget: Complete Collection [2 Discs] - (Full) - DVD',
#  'Funky Phantom [4 Discs] - Fullscreen - DVD',
#  'Initial D: Stage 4 - Part Two (2 Disc) - DVD',
#  'The NB Ridaz: Official DVD - DVD',
#  'Chico Buarque: MPB Especial - DVD',
#  'Tell Me Why: Computers/The Internet - DVD',
#  'Rounders/Swingers [2 Discs] - DVD',
#  'I Tried - DVD',
#  'Maximum Overdrive/Raw Deal - DVD',
#  'Dual Survival (2 Disc) - DVD',
#  "Breakin' vs. Krumpin' - DVD",
#  'Robotech: Protoculture Collection [21 Discs / Dubbed] - Dubbed - DVD',
#  'Star Wars - Dubbed Pan & Scan - DVD',
#  '.hack//Roots, Vol. 3: Tri-Edge [With MP3 Case] - Subtitle Special - DVD',
#  'Maxell - MiniDV Tape',
#  'MotoGP: Evolution of a Species - DVD',
#  'Cube 2: Hypercube - DVD',
#  'Perras - DVD',
#  'Easy VHS to DVD for Mac - Mac',
#  'Avid Xpress DV and Avid Xpress Pro Basic Editing Training - DVD',
#  'Furuno 600l Color LCD Fishfinder - DVD',
#  'Sunshine/The X-Files/The X-Files: I Want to Believe [3 Discs] - Widescreen Pan & Scan - DVD',
#  'Plasma Optics: Aquarium Sunsets Fireplace - DVD',
#  'Expresso Bongo - DVD',
#  "Webster's Millennium ASL: Say it by Signing - DVD",
#  'Gamers to Players Guitar - DVD',
#  "Making Opera: The Creation of Verdi's La Forza Del Destino - DVD",
#  'Straight to DVD [CD & DVD] - CD',
#  'Ultimate Beginner Mega Pak: Dj Style - Turntable - DVD',
#  'Ticker - DVD',
#  'Wild Zero - (Ws Sub) - DVD',
#  'Der Untergang des Hauses Usher (Wiener Symphoniker) - DVD',
#  'Raw Footage [PA] - CD',
#  'Cmt Invitation Only: Reba - DVD',
#  'Anthrax: Oidivnikufesin (N.F.V.) - DVD',
#  'Blue Crane Digital - Introduction to the Canon Rebel T3i/600D Instructional DVD',
#  'Trust - DVD',
#  'Donnie McClurkin: Double Play [CD & DVD] - CD',
#  'Absolute Beginners: Bass Guitar - DVD',
#  'CIA 2903: Stepping Up With Seasun Zieger - DVD',
#  'Nero 10 Multimedia Suite Platinum HD - Windows',
#  'Chevelle: Live From the Norva - DVD',
#  'Phone Booth - Ws - DVD',
#  'Fiber Optics Research - DVD',
#  'Prof. Harold Video Flash Cards: Multiplication - DVD',
#  '123 Copy DVD Platinum - Windows',
#  'Magellan Maestro 4050 & 4250 - DVD',
#  'Mannheim Steamroller Meets The Mouse - DVD-Audio',
#  'Stankonia - DVD-Audio',
#  'Mulan - (Spec) - DVD',
#  'Musicpro Guides: Pro Tools 9 - Advanced Level - DVD',
#  'Ergo Proxy, Vol. 3: Cytotropism - Widescreen - DVD',
#  'Introduction to Editing with Final Cut Pro - DVD',
#  'Razzle Dazzle: A Journey Into Dance - Widescreen - DVD',
#  'A Guitar Odyssey: Wired For Sound - DVD',
#  'Live 2003 (2 Disc) (W/Cd) - DVD',
#  'Shredder - DVD',
#  'Red Heat - (Ws Spec Sub Dol) - DVD',
#  'Plain Dirty - (Ws Sub Dol Dts) - DVD',
#  'Videos - DVD',
#  'Underoath: 777 - DVD',
#  'Graffiti Bridge - (Ws Sub Dol) - DVD',
#  'No Time To Bleed (CD+DVD) (Box) - CD',
#  'Nicholas Byrd: Magic with the iPhone - DVD',
#  'Sony - MiniDV Digital Video Cassettes (3-pack)',
#  'Sony - 5-Pack 90-Minute Hi-Fi Audio Cassettes',
#  'Wit - DVD',
#  'Man With A Video Camera - DVD',
#  'Prefontaine - DVD',
#  'Tenchi Muyo Gxp - Vc2 (8pc) - Box - DVD',
#  'Horizons [CD & DVD] - CD',
#  'Holes - (Ws) - DVD',
#  'Tuner Transformation: Complete Overhaul - DVD',
#  'Greater Tuna - DVD',
#  'Tex - DVD',
#  'Blank Check - DVD',
#  '16 Blocks - DVD',
#  'Science in Action: Lenses & Mirrors - DVD',
#  'DVD',
#  'Mimic/Mimic 2 [2 Discs] - DVD',
#  'Crack DVD, Vol. 7 - Fullscreen - DVD',
#  'Broken Frames [CD & DVD] - CD',
#  'Generation Kill [3 Discs] - DVD',
#  'Ichi - DVD',
#  'Soda Stereo: Confort y Musica Para Volar - DVD',
#  'Still Life [CD/DVD] [CD & DVD] [Digipak] - CD',
#  'Prof. Harold Video Flash Cards: Addition - DVD',
#  'Armin Van Buuren: Armin Only - Mirage - DVD',
#  'Flight 93/Partition - DVD',
#  'Windows Vista For Dummies - DVD',
#  'Magellan Roadmate 2000/2200T - DVD',
#  'True Stories I Made For (CD+DVD) - CD',
#  'Identity - (Full Ws Dub Spec Sub Dol) - DVD',
#  'Sometimes They Come Back - Pan & Scan - DVD',
#  'WALL-E - Special - DVD',
#  'Plat&#xE9;e - DVD',
#  'Universal Remote - DVD',
#  'Raymarine C Series: C90W Chartplotter/Fishfinder - DVD',
#  'Spy Hard - DVD',
#  "Freezer Burn - Collector's - DVD",
#  'Running Time - DVD',
#  'Videomaker Tips & Tricks: Green Screen Tips and Tricks - DVD',
#  'PowerDVD 11 Ultra - Windows',
#  "Blackberry's Greatest Videos - DVD",
#  'Atl - DVD',
#  'Con Air - Expanded - DVD',
#  "It'S Entertainment - DVD",
#  'How to Steal a Million - (Ws Dub Sub) - DVD',
#  'TP.3 Reloaded [CD & DVD] [PA] - CD',
#  'The Howling - (Std Ws Spec Sub Dol) - DVD',
#  'Collision - DVD',
#  'Make Your Own Videos Using a Camcorder - DVD',
#  'SDS Finance Module 4: Investing - DVD',
#  'DVD',
#  'HD Moods: AMOS Rebel - Blu-ray Disc',
#  'Kill Switch - DVD',
#  'Slices - DVD',
#  '123 Copy DVD Platinum HD Digital Media Studio - Windows',
#  'Stick It (2 Disc) - DVD',
#  'Zombie - (Spec) - DVD',
#  'My Name Is Bruce - Widescreen Dts - Blu-ray Disc',
#  'Part II [CD/DVD] [CD & DVD] [EP] [PA] - CD',
#  'NOVA: Power Surge - DVD',
#  'Flickering Lights - Subtitle - DVD',
#  'Norbit - DVD',
#  'PCU/Airheads [2 Discs] - DVD',
#  'My Dog Skip/Saving Shiloh - DVD',
#  'Last Kiss/Failure to Launch [2 Discs] - DVD',
#  '123 Copy DVD Gold - Windows',
#  'How to Frame a Figg - DVD',
#  'Short Circuit - (Ws Dol) - DVD',
#  'Garmin Etrex 10, 20, 30 - DVD',
#  'Cellular - (Ws Sub Ac3 Dol) - DVD',
#  'Ab 3.5 (Bonus Dvd) - CD',
#  'Sybil - Subtitle - DVD',
#  'Videos - UMD',
#  'I Know My First Name Is Steven - Fullscreen - DVD',
#  'Remote Control War - DVD',
#  'Designing Effective Desktop Graphics - DVD',
#  'Advanced Pro Tools, Vol. 3 - DVD',
#  'The Running Man - (Full Ws Rmst Spec Dol) - DVD',
#  'Garmin Forerunner 610 - DVD',
#  'Initial D: Third Stage - DVD',
#  'Snuff Box (2 Disc) (W/Cd) - DVD',
#  'Musicpro Guides: Logic Pro 9 - Beginner Level - DVD',
#  'Exitos Nortenos: Linea De Oro En Dvd - DVD',
#  'Chaos in Motion: 2007-2008 [CD & DVD] [Box] - CD',
#  'S.O.D.: Speak English Or Live - DVD',
#  'Negima, Vol. 3: Magic 301 - Practical Application of Magic - DVD',
#  'Raw Footage - CD',
#  'Criterion Hat - DVD',
#  'Quest for Fire - DVD',
#  '10 Minute Solution: Rapid Results Fat Burner - DVD',
#  'Fun and Fancy Free - DVD',
#  'Lightrhythm Visuals: Aple EP - DVD',
#  'Pinnacle Systems - Dazzle DVD Recorder HD',
#  'Learn Guitar in 21 Days - DVD',
#  'Photo DVD 4.0 - Windows',
#  'Zebra: The DVD - DVD',
#  'Garmin Forerunner 405 - DVD',
#  'Clerks - UMD Video for Sony PSP',
#  'Beginning Electric Slide Guitar - DVD',
#  'Bleach: Fade to Black - Dubbed Dts - Blu-ray Disc',
#  'Triangle - DVD',
#  'Digital Innovations - DvdDr Laser Lens Cleaner for DVD Players',
#  'Instant Expert: Science and Technology: The Story of Oil - DVD',
#  'Identity/The Secret Window [2 Discs] - DVD',
#  "Still Here: Blackberry's Greatest Collection - DVD",
#  'Fractal Experience - 3-D - VHS',
#  'Z-Ro [Slowed and Chopped] [CD & VHS] [PA] [Slow] - CD',
#  'Disney - Cars 7" Portable DVD Player - Red/Black',
#  'Transporter - DVD',
#  'Nero Video Premium HD - Windows',
#  'Man on the Moon II:... [CD & DVD] [PA] [Digipak] - CD',
#  'Something Like a Business - DVD',
#  'Rounders/Swingers [2 Discs] - 2 Pack - DVD',
#  'The Passing - DVD',
#  'Ancient Ink - DVD',
#  'Basic Video Production: Camera Operation - DVD',
#  'Boot Camp Clik: Video Surveillance - DVD',
#  'Airport Terminal Pack [4 Pack] - DVD',
#  'Spanglish/As Good As It Gets [2 Discs] - 2 Pack - DVD',
#  'Magellan Explorist GC - DVD',
#  'No Such Thing - Ws - DVD',
#  'Get A Life (10pc) - Box - DVD',
#  'Panasonic - MiniDV Cassette',
#  'Side Out - (Ws Dol) - DVD',
#  'Our Planet (10pc) (W/Cd) - DVD',
#  'Power Rangers Rpm 2 - DVD',
#  "You've Got Mail - DVD",
#  'Pt 24/7 - DVD',
#  'Enclosure 7: Harry Partch - DVD',
#  'Seven - (Ws Ac3 Dol Dts) - DVD',
#  'Latter Days - (Ws) - DVD',
#  'The Time Machine - DVD',
#  'Semi-Tough/Gator [2 Discs] - DVD',
#  'Made In Germany (CD+DVD) - CD',
#  'DVD',
#  'Easy CD & DVD Burning - Windows',
#  'Only the Strong - DVD',
#  'Moving Pictures [CD & DVD] [Digipak] - CD',
#  'Ready, Fire, Aim - DVD',
#  'The Invisible - DVD',
#  'How To Be A Megastar 2.1 (2 Disc) (W/Cd) - DVD',
#  'Chromeskull: Laid to Rest 2 - DVD',
#  'Cure for the Cable Guy [CD & DVD] [PA] - CD',
#  'Yankeeography 1-4 (12pc) - DVD',
#  'Tell Me Why, Vol. 25: Computers - DVD',
#  'Against the Current - DVD',
#  '123 Copy DVD - Windows',
#  'Terminal/Catch Me If You Can 2pk Sbs - DVD',
#  'Il Grido - Subtitle - DVD',
#  'Show Me Science Advanced: Engineering - Tiny Nano World - DVD',
#  'Learning Html - DVD',
#  'Verbatim - DigitalMovie 10-Pack 8x DVD-R Disc Blister',
#  'AMotion [CD & DVD] - Limited - DVD',
#  'Stained Glass Windows - DVD',
#  'Motorama - Movie - DVD',
#  'Crash Test - DVD',
#  'Initial D: Stage 4 - Save (4 Disc) - Box - DVD',
#  'Sony - 60-Minute Microcassettes (4-pack)',
#  'Out for a Kill - (Ws Dub Sub Dol) - DVD',
#  'Music Pro Guides: Cubase 6 - Beginner/Intermediate Level - DVD',
#  'Easy VHS to DVD - Windows',
#  'Basic Blue Screen & Green Screen Photography - DVD',
#  'Co Mi Zrobisz Jak Mnie Zlapiesz - DVD',
#  'Gacy - DVD',
#  'Macross: Complete Collection (8pc) - DVD',
#  'Raymarine A50/50D, A57D, A70/70D GPS/Chartplotter/Fishfinder - DVD',
#  'Dvd Success Series: Real Estate (6pc) - DVD',
#  'Super - DVD',
#  'Message in a Cell Phone - DVD',
#  'Murda Muzik - (Dol) - DVD',
#  'Medical Science Careers - DVD',
#  'Bleach: Fade to Black - Dubbed Dts - DVD',
#  "Dragon Drive, Vol. 8: Ri-On's Plot - Subtitle Dolby - DVD",
#  'Our Planet (10pc) (W/Cd) - Box - DVD',
#  'YOU: Steps for Extending Your Warranty with Dr. Michael Roizen - DVD',
#  'Turntable Technique: The Art of the DJ - DVD',
#  'Tsubasa - Ovas - Uncut - DVD',
#  'Tool: Vicarious - DVD',
#  'Cherry - DVD',
#  'Clambake - Ws - DVD',
#  'Master With Cracked Fingers - Dubbed - DVD',
#  'Rules of the Road and Aids to Navigation - DVD',
#  'Armin Van Buuren: Armin Only - The Next Level - DVD',
#  'As Seen On TV - Slim Clip',
#  'Pioneer Days - B&W - DVD',
#  'Hd-Dvd Starter Pk Tomb Raider/Sky Capt/S - DVD',
#  'Adrienne Reed: Fat Burner - DVD',
#  'PCU - DVD',
#  "Expert Insight: Ultimate Player'S (3 Disc) - DVD",
#  'Animals Should Not Try to... [CD & DVD] - DVD',
#  'Humminbird Fishfinder 797c2 SL Combo - DVD',
#  'VCR [EP] - CD',
#  'Chicago - Ws - DVD',
#  'Mambo Caf&#xE9; - DVD',
#  'Digital Video Editing - DVD',
#  'Assume the Position With Mr. Wuhl - Dubbed - DVD',
#  "Home Recording Magazine's 100 Recording Tips and Tricks - DVD",
#  'It - DVD',
#  'Quickbooks Ultimate Lesson Guide 2011 (6pc) - DVD',
#  'A Cabinet of Curiosities [CD & DVD] [Box] - CD',
#  'Das Boot - (Ws Dub Sub Unct Ac3 Dol) - DVD',
#  'Tube Guitar Amplifier Service and Overhaul - DVD',
#  'Strange Brew - DVD',
#  'Popcorn - DVD',
#  'Conquering Death by PowerPoint: Second Edition - DVD',
#  'The Boost - (Ws Sub) - DVD',
#  'Sony - 30-Minute Microcassette Tapes with Jewel Cases (3-Pack)',
#  'Coby - DVD Player with JPEG Viewer',
#  'eXistenZ - DVD',
#  'Project Viper - DVD',
#  'Elf - (Full Ws Dub Ac3 Dol) - DVD',
#  'Geneshaft, Vol. 2: Halo - DVD',
#  'Gigi - DVD',
#  'Dunston Checks In - DVD',
#  'Puppet Master Collection [9 Discs] - DVD',
#  'Attack on Darfur - DVD',
#  'Understanding Digital Cameras - DVD',
#  'Splash - (Ws Aniv Spec) - DVD',
#  'MotoGP Review 2003 - DVD',
#  'Terminator - HD-DVD',
#  'Greatest [CD/2 DVD] [PA] - CD',
#  'Magellan Explorist 510, 610, 710 - DVD',
#  'Show Me Science Advanced: Solar Power - An Alternative Energy Source - DVD',
#  'Ultimate Beginner Mega Pak: Blues Keyboard - DVD',
#  'Fatty Drives the Bus - DVD',
#  'Speed - DVD',
#  'Garmin - TOPO U.S. 24K West DVD',
#  'JCVD - Blu-ray Disc',
#  'Raphael: 50 A&#xF1;os Despues - DVD',
#  'Air Supply: The Ultimate Performance - DVD',
#  'Mask - (Spec) - DVD',
#  '16 Horsepower: 16 HP - DVD',
#  'Sony - High-Definition MiniDV Digital Video Cassettes (2-Pack)',
#  'Who Am I? - Fullscreen - DVD',
#  'Dual! Parallel Trouble Adventure, Vol. 3: Artifacts - DVD',
#  'VNV Nation: Pastperfect - DVD',
#  'Regoregitated Sacrifice - DVD',
#  '8MM / 8MM 2 [2 Discs / Unrated / SBS] - DVD',
#  'Im Dschungel Ist Der Teufel Los - Dubbed - DVD',
#  'Home Theater Demo Featuring Mannheim Steamroller - DVD-Audio',
#  'Shake - DVD',
#  'DVD',
#  'Puscifer: Dozo - Limited - DVD',
#  'Live & Off The Record (CD+DVD) - CD',
#  'Celestial Navigation for the Complete Idiot - DVD',
#  'Caf&#xE9; - DVD',
#  "I'm a Cyborg, but That's OK - Subtitle - DVD",
#  'YouTube Videos and Music [CD & DVD] [PA] - CD',
#  'Honey, I Blew Up the Kid - DVD',
#  'Non-Linear Editing Using the Avid - DVD',
#  'For Richer or Poorer - Ws & Dts - DVD',
#  'With the Lights Out [CD & DVD] [Box] - CD',
#  'Machine Head - DVD-Audio',
#  'The Business Side of Successful Filmmaking: Film Financing Secrets - DVD',
#  'Forensic Files: Sex Crimes (2 Disc) - Fullscreen Dolby - DVD',
#  'Free Tempo [CD & DVD] [PA] - CD',
#  'Zonoscope [Special Edition/+DVD] [CD & DVD] [Box] - CD',
#  'Dbz: Dbox Two (6pc) - Box - DVD',
#  'Gung Ho - DVD',
#  'Automobiles: BMW - DVD',
#  'Ju-on - (Sub) - DVD',
#  'VHS to DVD 5.0 Deluxe - Windows',
#  'NKOTBSB [DVD] - CD',
#  'Lambada/Salsa - DVD',
#  'I.Q. - (Ws Sub Dol) - DVD',
#  'Tin Tan: In&#xE9;ditas de Tin Tan - 2 Pack - DVD',
#  'Live - DVD',
#  'Garmin Dakota 10, 20 - DVD',
#  'Abacab [CD & DVD] [Remaster] - CD',
#  '123 Copy DVD Gold - Windows',
#  'Tuner Transformation: Change My Ride Now - DVD',
#  'Spawn - Special - DVD',
#  'Commando - Pan & Scan - Blu-ray Disc',
#  'Windows 7 for Dummies with DVD - Other',
#  'Collateral (2pc) - (Ws Sub Ac3 Dol Dts) - DVD',
#  'Basic/SWAT [2 Discs] - DVD',
#  'Tony MacAlpine: Shred Guitar - Fullscreen - DVD',
#  'IK Multimedia - Miroslav Philharmonik Software',
#  'Signing Time!, Vol. 2: Playtime Signs - DVD',
#  'How to DIY: Home Security - DVD',
#  'Soca Gold 2011 [DVD] - Various CD+DVD - CD',
#  'Fast Track: No Limits - AC3 - DVD',
#  'See Spot Run - DVD',
#  'Prof. Harold Video Flash Cards: Subtraction - DVD',
#  'Disney - Princess 7" Portable DVD Player - Pink/White',
#  'Chrome Shelled Regios: Part Two (2 Disc) - DVD',
#  'DVD',
#  'Initial D: Stage 4 - Part One (2 Disc) - DVD',
#  'Best Of G-Force - DVD',
#  'Fuji - Superia 400 Film (4-pack, 96 exposures)',
#  'How Stuff Works: Food & Beverage - DVD',
#  'Vanishing Point - (Ws) - DVD',
#  "Director's Cut - CD",
#  'Pinnacle - DVD',
#  'Frequency - DVD',
#  'Pure - DVD',
#  'Gee [Bonus DVD] [Single] - CD',
#  'Coby - DVD Player with JPEG Viewer',
#  'Styles of Krump - DVD',
#  'American Visa/Rosario Tijeras [2 Discs] - 2 Disc - DVD',
#  "Skate Maps 3 - Collector's Dolby - DVD",
#  'Mixed Nuts - Ws - DVD',
#  'Initial D: Stage One - Save (4 Disc) - Box - DVD',
#  'Cure for the Cable Guy [CD & DVD] [Edited] [PA] - CD',
#  'Project 1950 [CD & DVD] [Limited] - CD',
#  'Volkerball (CD+DVD) - CD',
#  'My Science Project - DVD',
#  'Digital Cameras Made Easy - DVD',
#  'Sling Media - The Slingbox SOLO',
#  'Pro Tools, Vol. 1 - DVD',
#  'Garmin Ique 3200 PDA - DVD',
#  'Kathy Smith: Matrix Method - Burn and Sculpt Walking Circuit - DVD',
#  'Lessons in Visual Language: Lenses and Perspective - DVD',
#  'Sufis at the Cinema: 50 Years of Bollywood... - CD',
#  'My Name Is Bruce - Widescreen - DVD',
#  'Circus [CD & DVD] - CD',
#  'Monster - HDTV Calibration Wizard DVD',
#  'Stir of Echoes - (Spec) - DVD',
#  'Speed - DVD',
#  'Ergo Proxy: Box Set (4 Disc) - Box - DVD',
#  'Gigi - DVD',
#  'Demons Triple Feature [3 Discs] - DVD',
#  'Casper - (Ws Dub Sub Dol Dts) - DVD',
#  'Tool: Parabola - DVD',
#  'Shinobi - DVD',
#  'Late Orchestration - DVD',
#  'DVD',
#  'Yattering: Creative Chaos - DVD',
#  'CSR Entertainment Family: Welcome to CSR - DVD',
#  'Plasma Visions, Vol. 1: Reflex - DVD',
#  'Paycheck - (Ws Coll) - DVD',
#  'This Is Black Metal - DVD',
#  'Garmin Nuvi 350 - DVD',
#  'Beginning Film and Video Making: Camera and Lenses - DVD',
#  'Decoys - (Ws Sub Ac3 Dol) - DVD',
#  'Skidoo - DVD',
#  'Burnt Offerings - (Ws Sub) - DVD',
#  'Timeline - (Ws) - DVD',
#  'Crossfire Trail - DVD',
#  'Hello Kitty: Plays Pretend - Dubbed - DVD',
#  'Forensics: You Decide - DVD',
#  'Apocalypto - DVD',
#  'Torque - (Ws Dub Sub Dol) - DVD',
#  'Triangle - DVD',
#  'Miral - DVD',
#  'Help! - DVD',
#  'Show Me How: A Video Guide to Your iPod and iTunes - DVD',
#  'Dreamkeeper - (Dol) - DVD',
#  'MOONPHASE: BOX SET / (BOX) - Box - DVD',
#  'Freezer Burn: The Invasion of Laxdale - DVD',
#  'RKO 281 - DVD',
#  'Smart House - DVD',
#  'Cry - DVD-Audio',
#  'Monte Carlo - DVD',
#  'Denise Austin: Sculpt & Burn Body Blitz - Widescreen Dolby - DVD',
#  'Party Day! [DVD Amaray Box] [CD & DVD] - DVD',
#  'My Dog Skip/Saving Shiloh - Subtitle - DVD',
#  'Live Without A Net - DVD',
#  'DVD (with Bonus Tracks) - CD',
#  'Forensic Files: Death By Poison (2 Disc) - Fullscreen Dolby - DVD',
#  'How to Lose a Guy in 10 Days - Ws - DVD',
#  "21st Century Vinyl: Michael Fremer's Practical Guide to Turntable Set Up - DVD",
#  'Escaflowne - DVD',
#  'The Terminal - (Ws Dub Sub Ac3 Dol Dts) - DVD',
#  'Ableton Live 8: Beginner Level - DVD',
#  'Gidget: Complete Collection [2 Discs] - Fullscreen - DVD',
#  'Google Me - DVD',
#  'Nell - DVD',
#  'Dvd Surround Sound Sampler - DVD',
#  'Machine Head: Elegies - DVD',
#  'Forensic Files: Historic Cases (2 Disc) - Fullscreen Dolby - DVD',
#  'The Rock House Method Sampler: Learn from the New Generation of Heroes - DVD',
#  'Simple Life [2 Discs] - Subtitle Pan & Scan - DVD',
#  'MP Da Last Don - (Rpkg) - DVD',
#  'Camp - (Ws Sub Ac3 Dol) - DVD',
#  'HISTORY VALUE LINE: ANCIENT ROME (5PC) - DVD',
#  'The Entitled - DVD',
#  'Lo Mejor del Chavo del 8: El examen - Fullscreen - DVD',
#  'Speak - DVD',
#  'Go Ask Alice - DVD',
#  "Charlotte's Web - Pan & Scan - DVD",
#  'Joyride - (Full Ws Sub) - DVD']

# %%
#sample top keywords in each cluster (same as figure above, but more data)
cluster_labels = {}

for cluster_key in range(0,99):
    print(f"{{ cluster: {cluster_key}, top_words: {top_words(clusters[cluster_key], 20)}}}")
# Out:
# { cluster: 0, top_words: ['DVD', 'WWE:', 'Fullscreen', 'Ultimate', 'Blu-ray', 'Disc', 'AC3', 'UFC', 'Dolby', 'Greatest', 'vs.', '2010', 'Best', 'Discs]', 'Fighting', 'NFL:', 'Vol.', 'Season', 'Series', 'TNA']}
# { cluster: 1, top_words: ['DVD', 'CD', 'DVD]', '[CD', '(Ws', 'Discs]', 'Sub', 'Dol)', 'Disc)', 'Windows', 'Video', '[2', 'Vol.', 'Ws', 'Fullscreen', '(2', '[PA]', 'Box', 'Pro', 'Ac3']}
# { cluster: 2, top_words: ['CD', 'You', 'Me', 'Love', 'VINYL', 'All', 'My', 'Is', 'Your', 'Up', 'We', 'It', 'Life', 'on', '[PA]', 'This', '[ECD]', 'Heart', 'No', 'Like']}
# { cluster: 3, top_words: ['Subtitle', 'Widescreen', 'DVD', 'Dolby', 'AC3', 'Dubbed', 'Fullscreen', 'Dts', 'Blu-ray', 'Disc', 'UMD', 'Saw', 'Dead', 'III', 'One', 'Game', 'State', 'Black', 'Dirty', 'Blood']}
# { cluster: 4, top_words: ['Microwave', 'Cu.', 'Ft.', 'Stainless-Steel', 'Oven', 'Over-the-Range', 'Black', 'Built-In', 'Wall', 'GE', 'Electric', 'White', 'Convection', 'Mid-Size', 'Toaster', 'Single', 'Whirlpool', '30"', 'Frigidaire', '2.0']}
# { cluster: 5, top_words: ['DVD', 'Discs]', 'Complete', 'Disc)', 'Box', '[2', 'Series', 'Collection', 'Season', 'Subtitle', 'Vol.', '(2', '[3', 'Widescreen', 'Disc', 'Blu-ray', 'Fullscreen', '[4', 'Part', 'Dubbed']}
# { cluster: 6, top_words: ['Tablet', 'Black', 'Apple&#xAE;', 'Tablets', 'Memory', 'iPad&#xAE;', 'Digital', 'Most', 'Screen', 'Samsung', 'White', 'Clear', '16GB', 'Touch', 'Wi-Fi', '3G', 'Galaxy', 'Pen', 'ZAGG', '32GB']}
# { cluster: 7, top_words: ['Deck', 'Apple&#xAE;', 'In-Dash', '50W', 'Radio-Ready', 'iPod&#xAE;-/Satellite', 'CD', 'MOSFET', 'DVD', 'Radio-/HD', 'iPod&#xAE;-Ready', 'Sony', '52W', 'Kenwood', 'MP3', 'Playback', 'JVC', 'Pioneer', 'Marine', 'Clarion']}
# { cluster: 8, top_words: ['DVD', 'Live', 'Disc', 'Blu-ray', 'at', 'Dolby', 'CD', 'Tour', 'Dts', 'Concert', 'From', 'AC3', 'At', 'Widescreen', '[CD', 'DVD]', 'Rock', 'Hall', 'Music', 'Vol.']}
# { cluster: 9, top_words: ['Mobile', 'Phones', 'Case', 'Black', 'Series', 'HTC', 'OtterBox', 'Samsung', 'ZAGG', 'InvisibleSHIELD', 'BlackBerry', 'Clear', 'Platinum', 'Commuter', 'Motorola', 'EVO', 'DROID', '4G', 'Xentris', 'Wireless']}
# { cluster: 10, top_words: ['Home', 'Theater', 'Player', '3D', 'Receiver', 'Blu-ray', 'A/V', 'System', 'DVD', '5.1-Ch.', 'Refurbished', 'Wi-Fi', 'Samsung', 'Pass', 'Through', '7.1-Ch.', 'Portable', 'Sony', 'Built-In', 'Philips']}
# { cluster: 11, top_words: ['AC3', 'Subtitle', 'DVD', 'Widescreen', 'Dubbed', 'Fullscreen', 'Dolby', 'Blu-ray', 'Disc', "Director's", 'Man', 'Up', 'Anniversary', 'New', 'You', 'Twilight', 'Special', 'Me', 'Black', 'II']}
# { cluster: 12, top_words: ['Cu.', 'Ft.', 'Washer', 'White', 'Whirlpool', 'High-Efficiency', 'LG', 'Capacity', 'Laundry', 'GE', 'Pedestal', 'Washer/Dryer', 'Maytag', 'Samsung', '3.6', '9-Cycle', '11-Cycle', 'Steam', 'Ultra', 'Silver']}
# { cluster: 13, top_words: ['VINYL', '[LP]', '[PA]', 'Vinyl', 'CD', '12-Inch', 'Single', 'Disc]', '[12inch', '(Ogv)', '[Single]', 'Edition)', '[EP]', '(Limited', 'Is', 'Vol.', 'Various', 'White', 'My', 'No']}
# { cluster: 14, top_words: ['CD', '[ECD]', '[CD', 'DVD]', '[PA]', '[Digipak]', '[Import]', 'Icon', 'Live', 'It', '(CD+DVD)', 'Various', 'CD]', '[Remaster]', '[Hyper', '[Box]', 'All', 'Collection', 'On', 'Is']}
# { cluster: 15, top_words: ['Headset', 'Bluetooth', 'Wireless', 'Plantronics', 'Gaming', 'Black', 'Headphones', 'Sennheiser', 'Microphone', 'System', 'Stereo', 'Xbox', '360', 'Turtle', 'Beach', 'Ear', 'Jawbone', 'Force', 'Logitech', 'USB']}
# { cluster: 16, top_words: ['(Pair)', 'Cones', 'Speakers', 'Car', 'Polypropylene', '2-Way', '6"', '6-1/2"', 'Woofer', 'Coaxial', '3-Way', '9"', '5-1/4"', 'Pioneer', '4"', 'Marine', 'Infinity', 'JBL', 'Kenwood', 'Kicker']}
# { cluster: 17, top_words: ['Light', 'Black', 'Lighting', 'LED', 'Chauvet', 'American', 'DJ', 'Lasko', 'Fan', 'Heater', 'Solar', 'Silver', 'White', 'Tower', 'Gray', 'Mirror', 'Ceramic', 'Smart', 'Energizer', 'Honeywell']}
# { cluster: 18, top_words: ['Drive', 'Hard', 'External', 'USB', 'Black', '2.0', 'Western', 'Digital', 'Internal', 'Portable', 'Serial', 'ATA', 'Seagate', '1TB', 'My', '500GB', 'Solid', 'State', '2TB', 'FreeAgent']}
# { cluster: 19, top_words: ['Card', 'PCI', 'Graphics', 'Express', 'ATX', '1GB', 'GeForce', 'GDDR5', 'Power', 'Cooler', '2.0', 'Supply', 'Motherboard', 'CPU', 'Master', '(Socket', 'Series', 'Radeon', 'HD', 'GTX']}
# { cluster: 20, top_words: ['Headphones', 'Earbud', 'Over-the-Ear', 'Black', 'Skullcandy', 'Sennheiser', 'Sony', 'Ear', 'Stereo', 'White', 'Beats', 'Bud', 'DJ', 'AKG', 'Dr.', 'Dre', 'JVC', 'Blue', 'Microphone', 'By']}
# { cluster: 21, top_words: ['Battery', 'Lenmar', 'Lithium-Ion', 'Select', 'Laptops', 'Phones', 'Mobile', 'Series', 'HP', 'Dell', 'Most', 'Lithium-Polymer', 'Sony', 'Toshiba', 'Compaq', 'VAIO', 'Samsung', 'Acer', 'Apple&#xAE;', 'LG']}
# { cluster: 22, top_words: ['AC3', 'Widescreen', 'Blu-ray', 'Disc', 'Subtitle', 'Dubbed', 'Dolby', 'Dts', 'DVD', 'Disc)', '(2', 'Discs]', 'Man', 'Fullscreen', '(W/Dvd)', 'Trilogy', 'Last', 'Day', "Director's", 'Night']}
# { cluster: 23, top_words: ['Season', 'DVD', 'Discs]', 'Widescreen', 'Subtitle', 'Dolby', 'AC3', 'Complete', 'Dubbed', '[4', '[3', '[6', 'Fullscreen', 'Disc', 'Blu-ray', 'First', '[2', '[5', 'Second', 'One']}
# { cluster: 24, top_words: ['Mobile', 'Phone', 'Black', '(Unlocked)', 'Samsung', 'No-Contract', '(AT&T)', '(Sprint)', '(Verizon', 'Wireless)', 'LG', 'BlackBerry', 'HTC', '4G', '(T-Mobile)', 'Memory', 'Apple&#xAE;', 'White', 'Motorola', 'Refurbished']}
# { cluster: 25, top_words: ['Radio', 'Antenna', 'AM/FM', '2-Way', 'Black', '(Pair)', 'Clock', 'Midland', 'Digital', 'Satellite', '22-Channel', 'FRS/GMRS', 'Kit', 'Marine', 'Indoor', 'Radios', 'Wireless', 'Weather', 'CD', 'Tuner']}
# { cluster: 26, top_words: ['Tripod', 'Sunpak', 'Manfrotto', 'Mount', 'Series', 'Black', 'Celestron', 'Digital', 'GoPro', 'Camera', 'Binoculars', 'Telescope', '3D', 'Kit', 'Cameras', 'Head', 'Bushnell', 'Polaroid', 'Ball', '10']}
# { cluster: 27, top_words: ['Microphone', 'USB', 'Audio', 'Mixer', 'Behringer', 'Digital', 'System', 'DJ', 'Recorder', 'Interface', 'Recording', 'M-Audio', 'Black', 'Studio', 'Controller', 'Software', 'Voice', 'Pro', 'Sound', 'Condenser']}
# { cluster: 28, top_words: ['Kit', 'Vehicles', 'Installation', 'Metra', 'Select', 'Black', 'Scosche', 'or', 'Toyota', 'Stereo', 'Radio', 'DIN', 'Ford', 'Pocket', 'Later', 'Honda', 'Dash', 'Nissan', '2008', 'Double-DIN']}
# { cluster: 29, top_words: ['Monitor', 'Widescreen', 'Black', 'LED', 'LCD', 'Flat-Panel', 'HD', '23"', 'Samsung', 'Asus', '27"', 'Power', 'Acoustik', 'TFT-LCD', '24"', '20"', 'Acer', 'DVD', 'Gray', 'LG']}
# { cluster: 30, top_words: ['CD', 'Various', 'Music', 'Vol.', 'Best', 'Leonard', 'Hal', 'Sheet', 'DVD', 'Collection', 'Piano', '[PA]', 'Century', '20th', 'Songs', 'Tribute', 'Guitar', 'Very', 'Anthology', 'Live']}
# { cluster: 31, top_words: ['USB', 'Flash', 'Drive', '2.0', '4GB', '16GB', '8GB', 'SanDisk', 'Kingston', 'External', 'DataTraveler', 'Lexar', '32GB', 'Technology', 'Swivel', 'Tribeca', 'PNY', 'JumpDrive', 'Cruzer', 'Memory']}
# { cluster: 32, top_words: ['Card', 'Prepaid', 'Airtime', 'Wireless', 'Gift', '$50', 'Top-Up', 'Game', 'Mobile', 'Microsoft', 'Xbox', 'Cricket', '$10', '$25', '$30', '$20', 'Apple&#xAE;', 'Facebook', 'Virgin', 'Subscription']}
# { cluster: 33, top_words: ['Memory', 'Drive', 'Hard', 'Processor', '4GB', 'Desktop', '1TB', 'Intel&#xAE;', 'HP', 'Laptop', 'AMD', '500GB', 'All-In-One', 'Computer', 'Core&#x2122;', '6GB', 'Display', '8GB', 'II', 'Pavilion']}
# { cluster: 34, top_words: ['PlayStation', 'PSP', 'Xbox', 'Edition', 'Guide)', '(Game', '360', 'Hits', 'Greatest', 'Game', '3,', 'Nintendo', 'Bundle', '360,', 'Call', 'Pack', 'Sony', 'War', 'Windows', "Collector's"]}
# { cluster: 35, top_words: ['Case', 'Black', 'Camera', 'Bag', 'Lowepro', 'Logic', 'Backpack', 'Most', 'Digital', 'Cases', 'Gator', 'Carrying', 'Guitars', 'Cameras', 'Sony', 'Portable', 'AW', 'Manfrotto', 'Compact', 'Sling']}
# { cluster: 36, top_words: ['Player', 'MP3', 'Black', '4GB*', '8GB*', 'iPod', 'Apple&#xAE;', 'Generation', 'Latest', 'Model)', 'SanDisk', 'Sony', 'Video', 'Sansa', '2GB*', 'Walkman', 'Coby', 'Blue', 'Mach', 'Speed']}
# { cluster: 37, top_words: ['Charger', 'Power', 'Battery', 'Adapter', 'USB', 'AC', 'Apple&#xAE;', 'Black', 'Travel', 'System', 'Charging', 'Kit', 'Nintendo', 'Back-Up', 'iPhone&#xAE;', 'DigiPower', 'Sony', 'Inverter', 'Select', 'Vehicle']}
# { cluster: 38, top_words: ['Camera', 'Digital', 'Black', '14.0-Megapixel', 'Silver', 'Nikon', 'Canon', 'Olympus', '12.1-Megapixel', '14.1-Megapixel', 'Coolpix', 'PowerShot', 'Red', 'Sony', 'Refurbished', 'Blue', 'Cyber-shot', 'FinePix', 'Panasonic', 'Lens']}
# { cluster: 39, top_words: ['Apple&#xAE;', 'iPad&#xAE;', 'Case', 'Black', 'iPad&#x2122;', 'Tribeca', 'Folio', 'iPad', 'Hard', 'Sleeve', 'Belkin', 'Jacket', 'Stand', 'M-Edge', 'Accessories', 'Shell', 'Cases', 'Smart', '(3rd', 'Generation)']}
# { cluster: 40, top_words: ['DVD', 'Workout', 'Yoga', 'Pro-Form', 'Treadmill', 'Fitness', 'GoFit', 'Body', 'Fullscreen', 'Exercise', 'Jillian', 'Dance', 'Pilates', 'Elliptical', 'Ultimate', 'Power', 'Weight', 'Stamina', 'Cardio', 'Michaels']}
# { cluster: 41, top_words: ['Blu-ray', 'Disc', '3D', 'Disc)', '(2', 'Discs]', 'Widescreen', '[2', '[Blu-ray]', 'Harry', 'Discs', 'Potter', 'Collection', 'DVD', 'Subtitle', 'Pirates', 'Pan', 'Scan', '(3', 'Black']}
# { cluster: 42, top_words: ['TVs', 'Flat-Panel', 'Up', 'TV', 'Stand', 'Mount', 'Most', 'Black', 'Wall', 'BDI', 'or', '60"', '32"', 'Furniture', 'Extends', 'Tube', 'Sanus', 'Whalen', '42"', "Bell'O"]}
# { cluster: 43, top_words: ['DVD', 'Discs]', 'Widescreen', '[2', 'Collection', 'Vol.', 'Fullscreen', 'Subtitle', '[3', 'Best', 'Disc)', 'Dolby', 'Box', 'AC3', 'Disc', 'Comedy', 'Blu-ray', '[4', 'Dubbed', 'Movie']}
# { cluster: 44, top_words: ['Black', 'Watch', 'Sports', "Men's", 'Red', 'Digital', 'Casio', 'Eyewear', 'Gunnar', 'Clock', 'Sport', 'Blue', 'Game', 'Silver', 'T-Shirt', 'Team', 'Fabrique', 'Innovations', 'White', 'America']}
# { cluster: 45, top_words: ['Apple&#xAE;', 'iPod&#xAE;', 'iPhone&#xAE;', 'Black', 'Dock', 'Speaker', 'System', 'Clock', 'Radio', 'Portable', 'iHome', 'Select', 'Most', 'Sony', 'Alarm', 'iPhone', 'iPad&#xAE;', 'Digital', 'Cable', 'iPad&#xAE;,']}
# { cluster: 46, top_words: ['CD', 'Best', 'Various', '[PA]', 'Hits', 'Live', 'Very', 'Love', 'Songs', 'My', 'Tribute', 'Vol.', 'Greatest', 'at', 'Soul', 'Me', '[CD', 'DVD]', 'Music', 'from']}
# { cluster: 47, top_words: ['Cable', 'Technology', 'Hosa', 'Monster', 'Cord', 'USB', 'Belkin', 'Extension', 'Black', 'Adapter', "6'", 'Kit', "10'", 'Digital', 'Smart', 'Choice', 'Connector', 'White', 'Patch', 'Video']}
# { cluster: 48, top_words: ['Wireless-N', 'Switch', 'Router', 'Ethernet', 'NETGEAR', 'Adapter', '4-Port', 'USB', 'Wireless', 'D-Link', 'Gigabit', 'Linksys', 'Modem', 'Belkin', 'Dual-Band', 'Cisco', '2.0', 'Network', '10/100', 'Refurbished']}
# { cluster: 49, top_words: ['Widescreen', 'DVD', 'Fullscreen', 'Blu-ray', 'Disc', 'Dubbed', 'AC3', 'Dts', 'Special', 'Dolby', 'You', 'One', 'Pan', 'Scan', 'Love', 'No', 'It', 'Kill', 'Down', 'High']}
# { cluster: 50, top_words: ['CD', 'Greatest', 'Hits', '[Remaster]', 'Edition)', '(Bonus', '(Deluxe', '[Bonus', 'Various', '(Remastered)', '[PA]', 'Tracks]', 'Edition]', 'Tracks)', '[Deluxe', 'DVD]', '[CD', 'Vol.', 'Collection', '(CD+DVD)']}
# { cluster: 51, top_words: ['30"', 'Range', 'Stainless-Steel', 'Freestanding', 'Self-Cleaning', 'Electric', 'Gas', 'Convection', 'GE', 'Black', 'Cooktop', 'Frigidaire', 'Whirlpool', 'Built-In', 'Hood', 'White', 'Slide-In', '36"', 'Oven', 'Double']}
# { cluster: 52, top_words: ['Lens', 'Cameras', 'Nikon', 'Canon', 'Digital', 'SLR', 'Zoom', 'Filter', 'Tiffen', 'Sony', 'Telephoto', 'Nikkor', 'Select', 'USM', 'AF-S', 'DX', 'EF', 'Alpha', 'ED', 'f/2.8']}
# { cluster: 53, top_words: ['Cartridge', 'Printer', 'HP', 'Ink', 'Black', 'Brother', 'Wireless', 'Network-Ready', 'Photo', 'Epson', 'Canon', 'All-In-One', 'Paper', 'Inkjet', 'Laser', 'Lexmark', 'Print', 'Color', 'Kodak', 'Pack']}
# { cluster: 54, top_words: ['Apple&#xAE;', 'Case', 'iPod&#xAE;', 'touch', 'iPhone&#xAE;', '4th-Generation', 'Black', 'Tribeca', 'Shell', 'Hard', 'Griffin', 'Technology', 'OtterBox', 'Series', 'Riot', 'Outfitters', 'Blue', 'Belkin', 'Incase', 'White']}
# { cluster: 55, top_words: ['Nintendo', 'Wii', 'DS', '3DS', 'Game', 'DSi', 'Mario', 'Super', 'dreamGEAR', 'LEGO', 'LeapFrog', 'Kit', 'Disney', 'Pack', '3D', 'Party', 'Edition', 'Starter', 'Bundle', 'Learning']}
# { cluster: 56, top_words: ['Ft.', 'Cu.', 'Refrigerator', 'Water', 'Thru-the-Door', 'Ice', 'Stainless-Steel', 'French', 'Door', 'Side-by-Side', 'White', 'Frigidaire', 'Black', 'GE', 'Whirlpool', 'Samsung', 'Freezer', 'Top-Mount', 'LG', 'Compact']}
# { cluster: 57, top_words: ['Black', 'Stand', 'Storage', 'Speaker', 'Multimedia', 'Cabinet', 'On-Stage', 'Mount', 'Series', 'Microphone', 'Atlantic', 'Tower', 'Sanus', 'Ashlin', 'Rack', 'Laptop', 'Ultimate', 'Stands', 'Keyboard', 'Safe']}
# { cluster: 58, top_words: ['Widescreen', 'DVD', 'Blu-ray', 'Disc', 'Dubbed', 'Fullscreen', 'Special', "Collector's", 'Discs]', 'Disc)', '[2', '(2', 'Subtitle', 'Dolby', 'Dead', 'AC3', "Director's", 'Man', 'Collection', 'Last']}
# { cluster: 59, top_words: ['Chair', 'Leather', 'TheaterSeatStore', 'Home', 'Theater', 'Seating', 'Black', 'Desk', 'Baseline', 'Furniture', 'Curved', 'Office', 'Video', 'Bush', 'Star', 'Computer', 'Magnolia', 'Sauder', '4-Seat', 'Gaming']}
# { cluster: 60, top_words: ['Disc', 'Spindle', 'Drive', 'DVD&#xB1;RW/CD-RW', 'CD', 'Double-Layer', 'External', 'Case', 'Memorex', 'Verbatim', '8x', 'USB', '2.0', 'Logic', '16x', 'Black', 'CD/DVD', 'DVD+R', 'DVD', 'CD-R']}
# { cluster: 61, top_words: ['Vacuum', 'Bagless', 'HEPA', 'Upright', 'Filter', 'Cleaner', 'BISSELL', 'Hoover', 'Air', 'Steam', 'Replacement', 'Dyson', 'Canister', 'Black', 'Purifier', 'White', 'Pet', 'Humidifier', 'Blue', 'Cordless']}
# { cluster: 62, top_words: ['Laptop', 'Case', 'Black', 'Sleeve', 'M-Edge', 'Accessories', 'Jacket', 'Kindle', 'Backpack', 'MacBook&#xAE;', 'Apple&#xAE;', 'Laptops', 'Targus', 'Keyboard', 'Amazon', 'Digital', 'Readers', 'Kobo', 'Incase', 'Red']}
# { cluster: 63, top_words: ['Battery', 'Lithium-Ion', 'Select', 'Lenmar', 'Digital', 'Cameras', 'Rechargeable', 'Energizer', 'DigiPower', 'Batteries', 'Canon', 'Camcorders', 'Nikon', 'Panasonic', 'NiMH', 'Pack', 'Duracell', 'Sony', 'Cordless', '(2-Pack)']}
# { cluster: 64, top_words: ['Remote', 'Controller', 'PlayStation', 'Wireless', 'Xbox', '360', 'Nintendo', 'Universal', 'Wii', 'Black', 'Sony', 'Logitech', 'Pro', 'Mad', 'Catz', 'Control', 'Microsoft', 'Edition', 'Harmony', 'Gaming']}
# { cluster: 65, top_words: ['DVD', 'Season', 'Discs]', 'Complete', '[4', '[3', 'First', 'Fullscreen', '[6', '[2', 'Second', 'Disc)', 'One', 'Widescreen', '[5', 'Seasons', 'Series', 'Third', 'Blu-ray', 'Disc']}
# { cluster: 66, top_words: ['Dryer', 'White', 'Cu.', 'Ft.', 'Electric', 'Gas', 'Capacity', 'BTU', 'Steam', 'Air', 'Conditioner', 'Frigidaire', 'LG', '7.4', '7.3', '9-Cycle', '7.0', 'Window', 'Whirlpool', 'Samsung']}
# { cluster: 67, top_words: ['CD', '[Digipak]', '[PA]', '[CD', 'DVD]', '[ECD]', '20th', 'Best', '[Deluxe', 'Century', 'Masters', 'Live', '[Bonus', 'Various', 'on', 'The...', 'Love', 'Edition]', 'You', 'Is']}
# { cluster: 68, top_words: ['Vehicles', 'Select', 'Harness', 'Metra', 'Scosche', 'Wiring', 'Adapter', 'Interface', 'GM', 'Speaker', 'Most', 'Later', 'Wire', 'Radio', 'Antenna', 'Black', 'or', 'Ford', 'Nissan', 'Honda']}
# { cluster: 69, top_words: ['Processor', 'Display', 'Laptop', 'Intel&#xAE;', 'Memory', 'Drive', 'Core&#x2122;', 'Hard', '4GB', '15.6"', 'Black', 'HP', 'AMD', 'i5', 'i3', 'Pavilion', '500GB', '17.3"', 'Refurbished', 'i7']}
# { cluster: 70, top_words: ['Black', 'Pedal', 'Drum', 'Guitars', 'Electric', 'Cymbal', 'Turntable', 'Bass', 'Most', 'Drumsticks', 'Wood', 'Guitar', 'BOSS', 'Zildjian', 'Tuner', 'Set', 'DJ', 'Behringer', 'Sound', 'Natural']}
# { cluster: 71, top_words: ['System', 'Monitor', 'Digital', 'Wireless', 'Surveillance', 'Camera', 'Lorex', 'Livescribe', 'Scanner', 'Calculator', 'Heart', 'Rate', 'Security', 'Black', 'Directed', 'Electronics', 'Detector', 'Pressure', 'Blood', 'Indoor/Outdoor']}
# { cluster: 72, top_words: ['Keyboard', 'Wireless', 'Keys', 'Sony', 'Portable', 'VAIO', 'Full-Size', 'Casio', 'Keyscaper', 'Gaming', 'Touch-Sensitive', '61', 'Adesso', 'Logitech', 'Laptops', 'Series', 'Black', '88', 'Skin', 'Yamaha']}
# { cluster: 73, top_words: ['Projector', 'Optoma', '3D', 'DLP', 'Adapter', 'Video', 'Screen', 'StarTech.com', 'Glasses', 'Mount', 'White', 'Projecta', 'Select', 'Projectors', 'Lamp', 'Epson', 'Mini', 'Vivitek', 'Black', 'HDMI']}
# { cluster: 74, top_words: ['DVD', 'Discs]', '[2', 'Widescreen', 'Blu-ray', 'Collection', 'Disc', 'Fullscreen', 'Subtitle', 'Special', 'Disc)', 'Movie', 'Dead', 'Night', '(2', 'Halloween', 'CD', 'Anniversary', 'Dark', 'B&W']}
# { cluster: 75, top_words: ['Camcorder', 'HD', 'Flash', 'Memory', 'Black', 'Sony', 'LCD', 'Digital', 'Webcam', 'JVC', 'Video', 'Refurbished', '3"', 'Monitor', 'Red', 'High-Definition', 'Silver', 'Blue', 'Recorder', 'Touch']}
# { cluster: 76, top_words: ['Subwoofer', 'Amplifier', '10"', 'Kicker', 'Enclosure', '4-Ohm', '12"', 'Class', 'Series', 'Single-Voice-Coil', 'Dual-Voice-Coil', 'Atrend', 'Bridgeable', 'Dual', 'Audio', 'AB', 'Powered', 'Sealed', 'MOSFET', '2-Channel']}
# { cluster: 77, top_words: ['Dolby', 'DVD', 'Widescreen', 'AC3', 'Subtitle', 'Blu-ray', 'Disc', 'Fullscreen', 'Dts', 'Dubbed', 'Special', 'Discs]', '[3', 'Vol.', 'Movie', 'Disc)', 'Love', 'Series', 'Dead', 'Complete']}
# { cluster: 78, top_words: ['System', 'Phone', 'DECT', '6.0', 'Cordless', 'Expandable', 'Digital', 'Answering', 'Panasonic', 'Corded', 'AT&T', 'Handset', 'Expansion', 'Speakerphone', 'Systems', 'Caller', 'ID', 'VTech', 'Select', 'Uniden']}
# { cluster: 79, top_words: ['Stainless-Steel', 'Black', 'KitchenAid', 'Cuisinart', 'Maker', 'White', 'Coffeemaker', 'Cooker', 'Food', 'Mixer', 'Stand', 'Coffee', 'Series', 'Blender', 'Pro', 'Silver', 'Keurig', 'Wine', 'Espresso', '12-Cup']}
# { cluster: 80, top_words: ['DVD', 'Christmas', 'Widescreen', 'Blu-ray', 'Fullscreen', 'Disc', 'Santa', 'Dubbed', 'Holiday', 'Subtitle', 'Special', 'Discs]', 'Carol', 'AC3', '[2', 'Dolby', 'Very', 'CD', 'Grinch', 'Anniversary']}
# { cluster: 81, top_words: ['HDTV', 'Class', '1080p', '60Hz', 'LED', 'LCD', '720p', '3D', '120Hz', 'Samsung', 'Smart', 'Plasma', '600Hz', 'Refurbished', '32"', '46"', 'LG', 'Toshiba', 'Panasonic', 'Sony']}
# { cluster: 82, top_words: ['Windows', 'Mac/Windows', 'Adobe', 'Mac', 'Edition', 'Upgrade', 'Suite', '2011', 'Home', 'Version', '2012', 'Premium', 'Pro', 'Creative', '5.5', '2010', 'Microsoft', 'Student', 'Sims', 'Office']}
# { cluster: 83, top_words: ['CD', 'Karaoke:', 'Various', 'Party', 'Karaoke', 'Tyme', 'Vol.', '[CD+G]', 'DVD', 'Pop', 'Hits', 'Disney', 'Sing', 'Songs', 'Hits,', '10', 'System', 'Box', 'Nintendo', 'Wii']}
# { cluster: 84, top_words: ['Razor', 'Black', 'Philips', 'Scooter', 'Electric', 'Conair', 'Norelco', 'Pro', 'Rechargeable', 'Huffy', 'Bicycle', 'Toothbrush', 'Ceramic', 'White', 'Trimmer', 'Hair', 'Kit', 'Iron', 'Replacement', 'Remington']}
# { cluster: 85, top_words: ['Mouse', 'Wireless', 'Black', 'Optical', 'Gaming', 'Logitech', 'Pad', 'Microsoft', 'Razer', 'Mobile', 'Laser', 'Edition', 'SteelSeries', 'Blue', '3500', 'Keyboard', 'Silver', 'Red', 'Wild', 'Sales']}
# { cluster: 86, top_words: ['Speaker', '2-Way', '(Each)', '(Pair)', 'Speakers', 'Black', 'System', '6-1/2"', 'Bookshelf', 'White', '5-1/4"', 'Audio', 'Series', 'Bowers', 'Wilkins', 'Center-Channel', 'Bose&#xAE;', 'Floor', '(2-Piece)', 'Home']}
# { cluster: 87, top_words: ['DVD', 'Widescreen', '[2', 'Discs]', 'Sub', 'Subtitle', 'Dub', '(Ws', 'Dol)', 'Fullscreen', 'Blu-ray', 'Disc', 'My', 'You', 'Love', 'Dolby', 'Girl', 'Man', 'on', 'Special']}
# { cluster: 88, top_words: ['Memory', 'Card', 'Class', 'Desktop', '2GB', 'Secure', 'Digital', '4GB', 'High', 'DDR2', 'Capacity', 'DIMM', 'DDR3', '(SDHC)', 'Kit', 'Laptop', 'Technology', 'SoDIMM', '2-Pack', '8GB']}
# { cluster: 89, top_words: ['Dishwasher', '24"', 'Built-In', 'Tall', 'Tub', 'Stainless-Steel', 'Black', 'White', 'GE', 'Bosch', 'Whirlpool', 'KitchenAid', 'Series', 'Frigidaire', 'Evolution', 'Maytag', 'Ascenta', '18"', 'Built-in', 'Integra']}
# { cluster: 90, top_words: ['Guitar', '6-String', 'Full-Size', 'Electric', 'Black', 'Acoustic', 'Fender&#xAE;', 'Natural', 'Strings', 'Schecter', 'Acoustic/Electric', 'Guitars', 'Series', 'Cordoba', 'Bass', '4-String', 'Nylon', 'Strap', 'String', 'Dreadnought']}
# { cluster: 91, top_words: ['Cable', 'AudioQuest', 'Monster', 'HDMI', 'Audio', 'Speaker', 'Black', 'White', 'RCA', "3.3'", 'A/V', "6.6'", 'In-Wall', 'Video', 'Subwoofer', "6'", 'Platinum', 'Kicker', 'Stereo', "8'"]}
# { cluster: 92, top_words: ['CD', '[ECD]', 'Best', 'Various', 'Is', '[Edited]', 'You', 'Very', 'Time', 'My', 'No', '(Edited)', 'What', 'This', 'Back', 'It', '[Clean]', 'Gold', 'Live', 'We']}
# { cluster: 93, top_words: ['Subtitle', 'DVD', 'Widescreen', 'Dubbed', 'Blu-ray', 'Disc', 'Fullscreen', 'Dolby', 'Special', 'Dts', 'Disc)', "Collector's", 'B&W', 'AC3', 'Movie', 'Last', 'Discs]', 'Box', 'Vol.', '2:']}
# { cluster: 94, top_words: ['DVD', 'Discs]', 'Fullscreen', 'Widescreen', 'Dubbed', '[2', 'Subtitle', 'Dolby', 'Vol.', 'Collection', 'Disc)', 'Complete', 'Little', 'Blu-ray', 'Disc', 'Series', 'Adventures', '[4', '[3', 'Movie']}
# { cluster: 95, top_words: ['Protector', 'Surge', 'Power', 'Monster', 'PowerCenter', '8-Outlet', 'Belkin', '6-Outlet', 'Panamax', '11-Outlet', '360', 'Electrical', 'Home', '4-Outlet', '2-Outlet', 'Theater', 'Conditioner/Surge', 'White', 'High-Definition', 'Smart']}
# { cluster: 96, top_words: ['CD', 'Original', 'Soundtrack', '[Original', 'Soundtrack]', 'Music', '[PA]', 'Motion', 'Picture', '(Score)', 'Vol.', 'from', 'From', '[ECD]', 'Cast', 'Remastered', 'Twilight', 'Glee:', 'Score]', 'Edition']}
# { cluster: 97, top_words: ['CD', 'de', 'DVD', 'La', 'El', 'Various', 'Exitos', 'De', 'Vol.', '[CD', 'DVD]', 'Grandes', 'En', 'Los', 'el', 'Amor', 'en', 'Vivo', '[ECD]', '[PA]']}
# { cluster: 98, top_words: ['CD', '[PA]', '[ECD]', '[Digipak]', 'Best', 'Vol.', '[CD', 'Is', 'DVD]', 'It', 'You', 'Greatest', 'Black', 'No', 'All', 'Various', 'Hits', 'Live', 'Life', 'We']}

# %%
import pandas as pd

### Create Pandas dataframes for product_clusters
product_ids_labels= dict(zip(product_ids, labels))
pddf_product_ids_labels=pd.DataFrame.from_dict(product_ids_labels,orient='index',columns=['label'])
pddf_product_ids_labels['pid']=pddf_product_ids_labels.index

# %% [markdown]
# ## Listing 9.16

# %%
import sentence_transformers
import heapq

## get the top n clusters based on similairty with centers 
def get_top_labels_centers(query,centers ,N=2):
    q_emb = transformer.encode([query], convert_to_tensor=False)
    similarities = sentence_transformers.util.cos_sim(q_emb, centers)
    sim=similarities.tolist()[0]
    res = [sim.index(i) for i in heapq.nlargest(N, sim)]
    return res

### Get the cluster for the query based on prediction of the label
def get_query_cluster(query):
    q_emb = transformer.encode([query], convert_to_tensor=False)
    q_label=algo.predict(q_emb)
    return q_label

# %%
def get_cluster_description(clusterNum):
    return "_".join(top_words(clusters[clusterNum],5))

query="microwave"
#option 1: Find nearest cluster (KMeans)
kmeans_predict=get_query_cluster(query)[0]
print(f"KMeans Predicted Cluster:\n    {kmeans_predict} (" 
      + get_cluster_description(kmeans_predict) + ")")

#option 2: Find most similar cluster (Cosine similarity)
closest_cosine_similarity=get_top_labels_centers(query,centers,N=1)[0]
print(f"\nCosine Predicted Cluster:\n    {closest_cosine_similarity} (" 
      + get_cluster_description(closest_cosine_similarity) + ")")

#option 3: N-nearest clusters (Cosine similarity)
knn_cosine_similarity=get_top_labels_centers(query,centers,N=5)
print(f"\nKNN Cosine Predicted Clusters: {knn_cosine_similarity}")
for clusterNum in knn_cosine_similarity: print(f"    {clusterNum} (" 
      + get_cluster_description(clusterNum) +")")
# Out:
# KMeans Predicted Cluster:
#     4 (Microwave_Cu._Ft._Stainless-Steel_Oven)
#
# Cosine Predicted Cluster:
#     4 (Microwave_Cu._Ft._Stainless-Steel_Oven)
#
# KNN Cosine Predicted Clusters: [4, 79, 51, 56, 89]
#     4 (Microwave_Cu._Ft._Stainless-Steel_Oven)
#     79 (Stainless-Steel_Black_KitchenAid_Cuisinart_Maker)
#     51 (30"_Range_Stainless-Steel_Freestanding_Self-Cleaning)
#     56 (Ft._Cu._Refrigerator_Water_Thru-the-Door)
#     89 (Dishwasher_24"_Built-In_Tall_Tub)

# %%
sdf_id_labels=spark.createDataFrame(pddf_product_ids_labels).createOrReplaceTempView('products_clusters')
# Out:
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:474: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:486: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, series in pdf.iteritems():

# %%
# Load signal data to create user-product vectors 
signals_collection="signals"
signals_opts={"zkhost": "aips-zk", "collection": signals_collection}
df_signals = spark.read.format("solr").options(**signals_opts).load()
df_signals.createOrReplaceTempView("signals")

# %%
#Create User-product data set for personalization
spark.sql("""
select  distinct user, target as product_id , name  as product_name
from signals s join products_samples p on s.target=p.upc
""").createOrReplaceTempView("user_product")

df_user_p=spark.sql("""select user,product_id, product_name,label from user_product a join 
products_clusters b on a.product_id = b.pid """)

user_product_cluster_collection = "user_product_cluster"
create_collection(user_product_cluster_collection)
user_product_cluster_opts={"zkhost": "aips-zk", "collection": user_product_cluster_collection, "gen_uniq_key": "true", "commit_within": "5000"}
df_user_p.write.format("solr").options(**user_product_cluster_opts).mode("overwrite").save()

#rows=df_user_p.collect()
# Out:
# Wiping 'user_product_cluster' collection
# [('action', 'CREATE'), ('name', 'user_product_cluster'), ('numShards', 1), ('replicationFactor', 1)]
# Creating 'user_product_cluster' collection
# Status: Success

# %%
## get the top n clusters based on similarity with centers 
def get_top_clusters_for_embedding(embedding, N=2):
    similarities = sentence_transformers.util.cos_sim(embedding,centers)
    sim=similarities.tolist()[0]
    res = [sim.index(i) for i in heapq.nlargest(N, sim)]
    return res

# %% [markdown]
# ## Listing 9.16

# %%
# importiong the modules
import pandas as pd
import numpy as np
np.set_printoptions(4)
  

#Take user's product interests and return dataframe containing embedding and guardrail cluster
def get_user_embeddings(products=[]):
    values = []
    for product in products:
        values.append([product_ids_emb[product], 
                       get_top_clusters_for_embedding(product_ids_emb[product],1)[0]])
    column_names = ["embedding", "cluster"]

    return pd.DataFrame(data = np.array(values), 
                  index = products, 
                  columns = column_names)

def get_user_personalization_vector(query=None, user_items=[], query_weight=1, user_items_weights=[]):
    #by default, weight is split 1:1 (50% each) between the query embedding and the user_items_weight.
    #you can manually add weights for each user_item to influence how much each element counts.

    query_embedding = transformer.encode(query, convert_to_tensor=False) if query else None
    
    if len(user_items) > 0 and len(user_items_weights) == 0:
        user_items_weights = np.full(shape=len(user_items), fill_value=1/len(user_items))
            
    embeddings = [] 
    embedding_weights = []
    for weight in user_items_weights:
        embedding_weights.append(weight)
    for embedding in user_items:
        embeddings.append(embedding)
    if query_embedding.any():
        embedding_weights.append(query_weight)
        embeddings.append(query_embedding)
                
    return np.average(embeddings,
                      weights=np.array(embedding_weights),axis=0).astype("double") if len(embeddings) > 0 else None

# %% [markdown]
# ## Lsting 9.17

# %%
product_interests = [ #"883049181479",  #samsung stainless steel refrigerator, touchscreen
                      "7610465823828",  #hello kitty water bottle
                      "36725569478"]   #samsung stainless steel electric range
                      #"36725560475" ]  #samsung stainless steel double oven electric range

user_embeddings = get_user_embeddings(product_interests)
print(f"\nProducts Interactions for Personalization:\n {user_embeddings}")

query = "microwave"

unfiltered_personalization_vector = get_user_personalization_vector(
                            query=query,
                            user_items=user_embeddings['embedding'].to_numpy())
print("\nPersonalization Vector (No Cluster Guardrails):\n" + str(unfiltered_personalization_vector[0:5]).replace("]", "... ]"))


query_clusters=get_top_labels_centers(query,centers,N=5)
print("\nQuery Clusters ('microwave'):", query_clusters)

filtered_embeddings = user_embeddings[user_embeddings.cluster.isin(query_clusters)] #filter down to only items in the query clusters
print("\nProducts Filtered to Query Clusters:\n" + str(filtered_embeddings))

filtered_personalization_vector = get_user_personalization_vector(
                            query=query,
                            user_items=filtered_embeddings['embedding'].to_numpy())

print("\nFiltered Personalization Vector (With Cluster Guardrails):\n" + str(filtered_personalization_vector[0:5]).replace("]", "... ]"))
# Out:
# Products Interactions for Personalization:
#                                                         embedding cluster
# 7610465823828  [0.06417942, 0.041785527, -0.0017139543, -0.02...      44
# 36725569478    [0.0055417735, -0.024302173, -0.024139365, -0....      51
#
# Personalization Vector (No Cluster Guardrails):
# [ 0.0164 -0.0062 -0.02   -0.0317 -0.0161... ]
#
# Query Clusters ('microwave'): [4, 79, 51, 56, 89]
#
# Products Filtered to Query Clusters:
#                                                      embedding cluster
# 36725569478  [0.0055417735, -0.024302173, -0.024139365, -0....      51
#
# Filtered Personalization Vector (With Cluster Guardrails):
# [ 0.0018 -0.0227 -0.0256 -0.0369 -0.0254... ]
# /tmp/ipykernel_838/453913026.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return pd.DataFrame(data = np.array(values),

# %% [markdown]
# ## Listing 9.18

# %%
# 4- Get all items for the search query using solr index
## Get the top items from the query cluster for the user
### User search query using solr 
import sys
sys.path.append('..')
from aips import *
#query="Western Digital - Scorpio Blue 250GB Internal Serial ATA Hard Drive for Laptops Serial ATA interface; quiet performance; 1.5GB/sec data transfer rate"

query="microwave"

search_results = search(query=query, 
                        fields=["upc", "name", "manufacturer", "score"], 
                        sort="score desc, upc asc",
                        params={
                          "qf": "name manufacturer",
                          "defType": "edismax",
                          "rows": 100 })

print("Search Results w/ No Personalization:")
display(HTML(render_search_results(query, search_results["docs"][0:4])))
# Out:
# Search Results w/ No Personalization:
# <div id="demo">
#         <input style="width:50%" readonly type="text" name="q" value="microwave">
#         <input readonly type="submit" value="Search">
#
#     <div class="results">
#
#
#     </div>
# </div>
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/48231316835.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> LG - LMHM2017SW Microwave Oven - White | <strong>Manufacturer:</strong> LG</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/37988910427.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Panasonic - NNCD989S Microwave Oven - Stainless-Steel | <strong>Manufacturer:</strong> Panasonic</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/72244106916.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> West Bend - Microwave Popcorn Popper - Red | <strong>Manufacturer:</strong> West Bend</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/21331131393.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Hello Kitty - 0.7 Cu. Ft. Compact Microwave | <strong>Manufacturer:</strong> Hello Kitty</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>

# %%
from operator import itemgetter


def rerank_with_personalization(search_results, personalization_vector):
    search_result_docs = search_results["docs"]

    result_embeddings=np.array([ product_ids_emb[search_result_docs[x]['upc']] for x in range(
        len(search_result_docs))]).astype(float)

    similarities = sentence_transformers.util.cos_sim(
        personalization_vector, result_embeddings).tolist()[0]

    reranked = [similarities.index(i) for i in heapq.nlargest(len(similarities), similarities)]
    reranked, values = zip(*sorted(enumerate(similarities), key=itemgetter(1),reverse=True))

    return [ search_result_docs[i] for i in reranked ]


#Show results without guardrails    
print("Personalized search results (no category guardrails):")
reranked_seach_results_no_guardrails =  rerank_with_personalization(search_results, unfiltered_personalization_vector) 
display(HTML(render_search_results(query, reranked_seach_results_no_guardrails[0:4])))

#Show results with guardrails
print("Personalized search results (with category guardrails):")
reranked_seach_results_with_guardrails =  rerank_with_personalization(search_results, filtered_personalization_vector) 
display(HTML(render_search_results(query, reranked_seach_results_with_guardrails[0:4])))
# Out:
# Personalized search results (no category guardrails):
# <div id="demo">
#         <input style="width:50%" readonly type="text" name="q" value="microwave">
#         <input readonly type="submit" value="Search">
#
#     <div class="results">
#
#
#     </div>
# </div>
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/21331131393.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Hello Kitty - 0.7 Cu. Ft. Compact Microwave | <strong>Manufacturer:</strong> Hello Kitty</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/12505559105.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Electrolux - 1.5 Cu. Ft. Built-In Microwave - Stainless-Steel | <strong>Manufacturer:</strong> Electrolux</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/37988910045.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Panasonic - 1.2 Cu. Ft. Mid-Size Microwave - Stainless-Steel | <strong>Manufacturer:</strong> Panasonic</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/37988910182.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Panasonic - 1.2 Cu. Ft. Mid-Size Microwave - White | <strong>Manufacturer:</strong> Panasonic</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
# Personalized search results (with category guardrails):
# <div id="demo">
#         <input style="width:50%" readonly type="text" name="q" value="microwave">
#         <input readonly type="submit" value="Search">
#
#     <div class="results">
#
#
#     </div>
# </div>
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/12505559105.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Electrolux - 1.5 Cu. Ft. Built-In Microwave - Stainless-Steel | <strong>Manufacturer:</strong> Electrolux</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/37988910045.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Panasonic - 1.2 Cu. Ft. Mid-Size Microwave - Stainless-Steel | <strong>Manufacturer:</strong> Panasonic</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/37988909926.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Panasonic - 2.2 Cu. Ft. Full-Size Microwave - Stainless-Steel | <strong>Manufacturer:</strong> Panasonic</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>
#
#     	<div style="position: relative; width: 100%; height:auto; overflow: auto;">
# 	    	<div style="position: relative; float:left; width: 120px; margin-top:25px">
# 	    		<img style="width:100px; height: auto; max-height:150px" src="../data/retrotech/images/37988910250.jpg">
# 	    	</div>
# 	    	<div style="position:relative; float:left; clear:none; width: 80%; height:auto">
# 	    		<p><strong>Name:</strong> Panasonic - 2.2 Cu. Ft. Full-Size Microwave - Stainless-Steel | <strong>Manufacturer:</strong> Panasonic</p>
# 	    		<p>
# 	    		</p>
# 	    	</div>
#     	</div>
#
# 		<div style="position:relative; clear:both; content: ' '; display: block; height: 1px; margin-top: 10px; margin-bottom:20px">
# 			<hr style="color: gray; width: 95%;" />
# 		</div>

# %% [markdown]
# # Old ALS Code

# %%
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.feature import StringIndexer, IndexToString
from pyspark.sql.functions import col, explode

signals_collection = "signals"

# Load signals from Solr
signals_read_opts = {"zkhost": "aips-zk", "collection": signals_collection}
sql_filter = """select user, target, type
from signals
where user is not null and type='click'
"""
signals_df = spark.read.format("solr").options(**signals_read_opts).load()
signals_df.createOrReplaceTempView("signals")
signals_df = spark.sql(sql_filter)

# Encode 'user' and 'target' fields into integer IDs
indexer_user = StringIndexer(inputCol="user", outputCol="userId")
indexer_target = StringIndexer(inputCol="target", outputCol="itemId")

# %%
index_model_user = indexer_user.fit(signals_df)
index_model_target = indexer_target.fit(signals_df)
signals_df = index_model_user.transform(signals_df)
signals_df = index_model_target.transform(signals_df)

# Prepare data for ALS model
data = signals_df.select(col("userId").cast("int"), 
                         col("itemId").cast("int"), 
                         col("type").cast("int"))

# Split the data into training and test sets
(training, test) = data.randomSplit([0.8, 0.2])

# %%
# Initialize ALS model
als = ALS(maxIter=5, regParam=0.01, userCol="userId", itemCol="itemId", ratingCol="type", coldStartStrategy="drop")

# %%
# Train ALS model
model = als.fit(training)

# %%
# Train ALS model
model = als.fit(training)

# Generate top 10 product recommendations for each user
userRecs = model.recommendForAllUsers(10)

# Mapping back the 'userId' and 'itemId' to original 'user' and 'target' values
user_to_string_indexer = IndexToString(inputCol="userId", outputCol="user", labels=index_model_user.labels)
item_to_string_indexer = IndexToString(inputCol="itemId", outputCol="target", labels=index_model_target.labels)

userRecs = user_to_string_indexer.transform(userRecs)

# To convert the recommendations from array format to multiple rows,
# we explode the recommendations array
userRecs = userRecs.withColumn("recommendations", explode(userRecs.recommendations))

userRecs = item_to_string_indexer.transform(userRecs)

# Display the recommendations
userRecs.select("user", "recommendations.target", "recommendations.rating").show()
